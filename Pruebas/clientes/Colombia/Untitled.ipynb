# %%
import os
import sys
import re
import io
import numpy as np
import pandas as pd
import pdfplumber
import statistics

# %%
# Ruta al folder "Pruebas", donde están /clientes y /Archivos
project_root = "/Users/svonbergen/Desktop/Unilever/2.Automatizacion_aplicacion_pagos/Pruebas"
sys.path.append(project_root)

print("ROOT CORRECTO:", project_root)
# Out:
# ROOT CORRECTO: /Users/svonbergen/Desktop/Unilever/2.Automatizacion_aplicacion_pagos/Pruebas

# %%
try:
    from clientes.utils import *
    print("✅ Imports cargados desde clientes/Main/utils")
except Exception as e:
    print("❌ Error importando utils:", e)
# Out:
# ✅ Imports cargados desde clientes/Main/utils

# %%
root = project_root    # ✅ Archivos está acá, no dentro de clientes

rutas = {
    "pdf_remittance": os.path.join(root, "Archivos", "Remittance", "Colombia", "Remittance_euro.pdf"),
    "fbl5n":          os.path.join(root, "Archivos", "Cartera", "FBL5N_Euro.xlsx"),
    "salida":         os.path.join(root, "Archivos", "Template", "Colombia", "Template_HRC_euro.xlsx")
}

for k, v in rutas.items():
    print(k, "→", v, "| existe?", os.path.exists(v))
# Out:
# pdf_remittance → /Users/svonbergen/Desktop/Unilever/2.Automatizacion_aplicacion_pagos/Pruebas/Archivos/Remittance/Colombia/Remittance_euro.pdf | existe? True
# fbl5n → /Users/svonbergen/Desktop/Unilever/2.Automatizacion_aplicacion_pagos/Pruebas/Archivos/Cartera/FBL5N_Euro.xlsx | existe? True
# salida → /Users/svonbergen/Desktop/Unilever/2.Automatizacion_aplicacion_pagos/Pruebas/Archivos/Template/Colombia/Template_HRC_euro.xlsx | existe? True

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 procesar()
#
# Cell In[14], line 121, in procesar()
#     118     return merged
#     120 # --- Lectura del PDF ---
# --> 121 with pdfplumber.open(rutas["pdf_remittance"]) as pdf:
#     122     for pnum, page in enumerate(pdf.pages, start=1):
#     123         words = page.extract_words()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pdfplumber/pdf.py:95, in PDF.open(cls, path_or_fp, pages, laparams, password, strict_metadata, unicode_norm, repair, gs_path, repair_setting, raise_unicode_errors)
#      93     path = None
#      94 elif isinstance(path_or_fp, (str, pathlib.Path)):
# ---> 95     stream = open(path_or_fp, "rb")
#      96     stream_is_external = False
#      97     path = pathlib.Path(path_or_fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/svonbergen/Desktop/Unilever/2.Automatizacion_aplicacion_pagos/Pruebas/clientes/Archivos/Remittance/Colombia/Remittance_euro.pdf'
