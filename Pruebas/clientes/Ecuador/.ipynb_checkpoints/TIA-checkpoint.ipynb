# %%
import pdfplumber
import pandas as pd
import sys
import os
import re

# %%
#root = _project_root()
# --- Rutas de entrada/salida ---
rutas = {
#    "pdf_remittance": os.path.join( "..", "..", "Archivos", "Remittance", "Ecuador", "Remittance TIA.pdf"),
    "pdf_remittance": os.path.join( "..", "..", "Archivos", "Remittance", "Ecuador", "Remittance TIA 2.pdf"),
#    "fbl5n": os.path.join("..", "..", "Archivos", "Cartera", "FBL5N_Cenco.xlsx"),
    "salida": os.path.join("..", "..", "Archivos", "Template", "Colombia", "Template_HRC_Cenco.xlsx")
}
# Colocar el Customer ID del cliente
customer_id = 10267301

# %%
archivo_pdf = rutas["pdf_remittance"]

# %%
def extraer_facturas(archivo_pdf):
    filas = []

    with pdfplumber.open(rutas["pdf_remittance"]) as pdf:
        for pagina in pdf.pages:
            words = pagina.extract_words(x_tolerance=2, y_tolerance=3)
            lineas_dict = {}

            for w in words:
                y = round(w["top"])
                x = w.get("x", w.get("x0", 0))
                lineas_dict.setdefault(y, []).append((x, w["text"]))

            for y, contenido in sorted(lineas_dict.items()):
                linea = " ".join(t for _, t in sorted(contenido))
                if re.match(r"^\d{4}-\d{2}-\d{2}\s+\d+", linea):
                    filas.append(linea)

    registros = []
    for f in filas:
        numeros = re.findall(r"-?[\d,]+\.\d{2}", f)
        if len(numeros) < 3:
            continue

        bruto, ret, neto = [n.replace(",", "") for n in numeros[-3:]]
        parte_antes = f[:f.rfind(bruto)].strip()
        tokens = parte_antes.split()

        # Fecha y código plaza
        fecha = tokens[0]
        plaza_codigo = tokens[1]

        # Buscar posición del F, C o D
        tipo_idx = None
        for i, tok in enumerate(tokens):
            if tok in ["F", "C", "D"]:
                tipo_idx = i
                break

        if tipo_idx is None:
            print("⚠️ No se encontró tipo en:", f)
            continue

        # Plaza completa
        plaza_pago = " ".join(tokens[2:tipo_idx])
        tipo_letra = tokens[tipo_idx]
        documento = tokens[tipo_idx + 1]
        descripcion = " ".join(tokens[tipo_idx + 2:])

        # 🔧 Documento = Tipo + número
        documento_final = f"{tipo_letra} {documento}"
        tipo_texto = descripcion.strip()

        registros.append([
            fecha,
            f"{plaza_codigo} {plaza_pago}".strip(),
            tipo_texto,
            documento_final,
            bruto,
            ret,
            neto
        ])

    df = pd.DataFrame(
        registros,
        columns=[
            "Fecha",
            "Plaza Pago",
            "Documento",
            "Tipo",
            "Bruto",
            "Retención",
            "Neto a Pagar",
        ],
    )

    # Parche
    df[["Documento", "Tipo"]] = df[["Tipo", "Documento"]].copy()

    for c in ["Bruto", "Retención", "Neto a Pagar"]:
        df[c] = pd.to_numeric(df[c], errors="coerce")

    return df


# --- Ejecutar ---
df = extraer_facturas(rutas["pdf_remittance"])

# %%
df.head(100)
# Out:
#          Fecha                           Plaza Pago          Documento  \
# 0   2024-05-13  100 CENTRO DE DISTRIBUCION NACIONAL  C 001014000018522
# 1   2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303974
# 2   2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303975
# 3   2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303976
# 4   2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303977
# 5   2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303978
# 6   2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303979
# 7   2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303980
# 8   2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303981
# 9   2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303982
# 10  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304000
# 11  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304001
# 12  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304002
# 13  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304003
# 14  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304004
# 15  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304005
# 16  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304006
# 17  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304007
# 18  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304008
# 19  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304009
# 20  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304010
# 21  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304011
# 22  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304012
# 23  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304013
# 24  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304014
# 25  2024-05-07  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000304015
# 26  2024-04-28  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303589
# 27  2024-04-28  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303590
# 28  2024-04-28  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303591
# 29  2024-04-27  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303521
# 30  2024-04-26  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303427
# 31  2024-04-26  100 CENTRO DE DISTRIBUCION NACIONAL  F 013002000303428
#
#                                                  Tipo     Bruto  Retención  \
# 0           FOLIO 21013 REINTEGRO MES MAYO 68.40 0.00     68.40       0.00
# 1                      MERCADERIA REVENTA SECCION 016    464.53      -6.06
# 2   MERCADERIA REVENTA SECCION 016 2,058.43 -26.85...   2058.43     -26.85
# 3   MERCADERIA REVENTA SECCION 016 3,207.13 -41.83...   3207.13     -41.83
# 4   MERCADERIA REVENTA SECCION 014 2,604.34 -33.97...   2604.34     -33.97
# 5   MERCADERIA REVENTA SECCION 016 12,662.21 -165....  12662.21    -165.16
# 6   MERCADERIA REVENTA SECCION 016 9,001.03 -117.4...   9001.03    -117.40
# 7   MERCADERIA REVENTA SECCION 016 3,788.50 -49.42...   3788.50     -49.42
# 8   MERCADERIA REVENTA SECCION 016 5,773.59 -75.31...   5773.59     -75.31
# 9   MERCADERIA REVENTA SECCION 014 10,535.67 -137....  10535.67    -137.42
# 10  MERCADERIA REVENTA SECCION 016 6,589.89 -85.96...   6589.89     -85.96
# 11  MERCADERIA REVENTA SECCION 016 12,029.11 -156....  12029.11    -156.90
# 12  MERCADERIA REVENTA SECCION 016 9,362.97 -122.1...   9362.97    -122.13
# 13  MERCADERIA REVENTA SECCION 016 6,158.98 -80.33...   6158.98     -80.33
# 14  MERCADERIA REVENTA SECCION 016 16,172.11 -210....  16172.11    -210.94
# 15  MERCADERIA REVENTA SECCION 016 5,029.51 -65.60...   5029.51     -65.60
# 16  MERCADERIA REVENTA SECCION 016 5,615.19 -73.24...   5615.19     -73.24
# 17  MERCADERIA REVENTA SECCION 016 12,931.99 -168....  12931.99    -168.68
# 18  MERCADERIA REVENTA SECCION 016 7,477.18 -97.53...   7477.18     -97.53
# 19  MERCADERIA REVENTA SECCION 016 5,468.95 -71.33...   5468.95     -71.33
# 20  MERCADERIA REVENTA SECCION 016 10,653.40 -138....  10653.40    -138.96
# 21  MERCADERIA REVENTA SECCION 014 3,145.08 -41.02...   3145.08     -41.02
# 22  MERCADERIA REVENTA SECCION 014 15,832.97 -206....  15832.97    -206.52
# 23  MERCADERIA REVENTA SECCION 016 22,381.24 -291....  22381.24    -291.93
# 24  MERCADERIA REVENTA SECCION 016 5,185.35 -67.64...   5185.35     -67.64
# 25  MERCADERIA REVENTA SECCION 016 8,827.22 -115.1...   8827.22    -115.14
# 26  MERCADERIA REVENTA SECCION 016 10,506.65 -137....  10506.65    -137.04
# 27  MERCADERIA REVENTA SECCION 016 25,969.07 -338....  25969.07    -338.73
# 28  MERCADERIA REVENTA SECCION 014 67,041.16 -874....  67041.16    -874.45
# 29  MERCADERIA REVENTA SECCION 014 32,751.65 -427....  32751.65    -427.20
# 30  MERCADERIA REVENTA SECCION 016 9,206.34 -120.0...   9206.34    -120.08
# 31  MERCADERIA REVENTA SECCION 016 13,217.85 -172....  13217.85    -172.41
#
#     Neto a Pagar
# 0          68.40
# 1         458.47
# 2        2031.58
# 3        3165.30
# 4        2570.37
# 5       12497.05
# 6        8883.63
# 7        3739.08
# 8        5698.28
# 9       10398.25
# 10       6503.93
# 11      11872.21
# 12       9240.84
# 13       6078.65
# 14      15961.17
# 15       4963.91
# 16       5541.95
# 17      12763.31
# 18       7379.65
# 19       5397.62
# 20      10514.44
# 21       3104.06
# 22      15626.45
# 23      22089.31
# 24       5117.71
# 25       8712.08
# 26      10369.61
# 27      25630.34
# 28      66166.71
# 29      32324.45
# 30       9086.26
# 31      13045.44

# %%
print(f"\nTotal de filas: {len(df)}")
# Out:
# Total de filas: 50
