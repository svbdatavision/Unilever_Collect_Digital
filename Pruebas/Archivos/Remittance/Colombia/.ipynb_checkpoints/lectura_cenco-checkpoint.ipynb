# %%
import pdfplumber
import pandas as pd
import re

# ------------------------
# Configuración y patrones
# ------------------------
pdf_path = "Remittance_Cenco.pdf"

# Vouchers reconocidos
VOUCHERS = r"(FS|CH|DEC|NC|ND|LTG|FPM|DCA|DCF|DND|DAV|DCC|RPL|DAT|DEV|DPC)"
pat_inicio = re.compile(rf"^{VOUCHERS}\b", flags=re.IGNORECASE)

# Patrones para documentos específicos
pat_documento_dec = re.compile(r"\b(\d{4}-\d{7,20})\b")     # DEC
pat_documento_pmp = re.compile(r"\b(PMP\d{3,20})\b")        # PMP / LTG / FPM
pat_documento_fs_pair = re.compile(r"\b([A-Z0-9]{2,6})\s+(\d{5,12})\b")  # FS
pat_fecha = re.compile(r"\d{2}/\d{2}/\d{4}")                # Fecha

# Secciones posibles
SECCIONES = {"PERFUME", "DROGUE", "RANCHO", "PLATOS"}

# -----------------------
# Funciones utilitarias
# -----------------------

def normalize_whitespace(s: str) -> str:
    """Quita espacios extra y normaliza la cadena."""
    return re.sub(r"\s+", " ", s).strip()

def is_start_of_record(line: str) -> bool:
    """Verifica si una línea comienza con un voucher reconocido."""
    return bool(pat_inicio.match(line.strip()))

def merge_lines(lines):
    """
    Une todas las líneas de un mismo registro:
    - Si empieza con voucher → nuevo registro
    - Si no, se agrega al registro actual
    Esto asegura que multi-líneas en DESCRIPCION o TIENDA queden juntas.
    """
    registros = []
    buffer = ""

    for raw in lines:
        line = raw.strip()
        if not line:
            continue

        if pat_inicio.match(line):
            if buffer:
                registros.append(normalize_whitespace(buffer))
            buffer = line
        else:
            buffer += " " + line  # unir toda línea que no empieza con voucher

    if buffer:
        registros.append(normalize_whitespace(buffer))
    return registros

def extract_numeric_values_after_date(text: str):
    """Extrae todos los valores numéricos después de la fecha en la línea."""
    t = re.sub(r"[^\d\.,\-]+", " ", text)
    toks = [x for x in t.split() if x.strip() != ""]
    return [tk for tk in toks if re.search(r"\d", tk)]

# ------------------------
# Parsers por tipo de VOUCHER
# ------------------------

def parse_DEC(line, voucher):
    """Parsea registros tipo DEC, incluyendo especiales 'DTO POR ESCALA VOLU'."""
    line = normalize_whitespace(line)
    mfecha = pat_fecha.search(line)
    if not mfecha:
        return None
    fecha = mfecha.group(0)

    pre_date = line[len(voucher):mfecha.start()].strip()
    post_date = line[mfecha.end():].strip()

    prefix = "DTO POR ESCALA VOLU"
    if pre_date.startswith(prefix):
        descripcion = prefix
        rest = pre_date[len(prefix):].strip()
        # Capturar documento DEC seguido de todo lo que queda como tienda
        mdoc = re.match(r"(\d{4}-\d{7,20})(.*)", rest)
        if mdoc:
            documento = mdoc.group(1)
            tienda = normalize_whitespace(mdoc.group(2))
        else:
            documento = ""
            tienda = rest
    else:
        # Caso genérico DEC
        mdoc = pat_documento_dec.search(pre_date)
        if mdoc:
            documento = mdoc.group(1)
            descripcion = normalize_whitespace(pre_date[:mdoc.start()])
            tienda = normalize_whitespace(pre_date[mdoc.end():])
        else:
            documento = ""
            descripcion = pre_date
            tienda = ""

    # Extraer valores numéricos después de la fecha
    nums = extract_numeric_values_after_date(post_date)
    while len(nums) < 8:
        nums.append("0")
    valor, iva, ret_fuente, ret_iva, ret_ica, otros_imp, valor_pag = nums[:7]
    doc_soporte = nums[7]

    # Detectar sección dentro de DESCRIPCION o TIENDA
    seccion = ""
    for sec in SECCIONES:
        if sec in descripcion:
            seccion = sec
            descripcion = descripcion.replace(sec, "").strip()
            break
        elif sec in tienda:
            seccion = sec
            tienda = tienda.replace(sec, "").strip()
            break

    return {
        "VOUCHER": voucher,
        "DESCRIPCION": descripcion,
        "DOCUMENTO": documento,
        "TIENDA": tienda,
        "SECCION": seccion.upper(),
        "F. REGISTRO": fecha,
        "VALOR": valor,
        "IVA": iva,
        "RET. FUENTE": ret_fuente,
        "RET. IVA": ret_iva,
        "RET. ICA": ret_ica,
        "OTROS IMP.": otros_imp,
        "VALOR PAG": valor_pag,
        "DOC.SOPORTE": doc_soporte
    }

def parse_PMP(line, voucher):
    """Parsea vouchers tipo LTG y FPM."""
    m = pat_documento_pmp.search(line)
    if not m:
        return None
    documento = m.group(1)
    doc_start, doc_end = m.start(), m.end()
    descripcion = normalize_whitespace(line[len(voucher):doc_start])

    tail = line[doc_end:].strip()
    tokens_tail = tail.split()
    idx_sec = None
    for i, t in enumerate(tokens_tail):
        if t.upper() in SECCIONES:
            idx_sec = i
            break

    if idx_sec is None:
        mfecha = pat_fecha.search(tail)
        if not mfecha:
            return None
        fecha = mfecha.group(0)
        before_date = tail.split(fecha, 1)[0].strip()
        btoks = before_date.split()
        if btoks and btoks[-1].upper() in SECCIONES:
            seccion = btoks[-1]
            tienda = " ".join(btoks[:-1]).strip()
        else:
            tienda = before_date
            seccion = ""
    else:
        tienda = " ".join(tokens_tail[:idx_sec]).strip()
        seccion = tokens_tail[idx_sec]

    mfecha = pat_fecha.search(tail)
    fecha = mfecha.group(0)

    nums = extract_numeric_values_after_date(tail.split(fecha,1)[1])
    while len(nums) < 8:
        nums.append("0")
    valor, iva, ret_fuente, ret_iva, ret_ica, otros_imp, valor_pag = nums[:7]
    doc_soporte = nums[7]

    return {
        "VOUCHER": voucher,
        "DESCRIPCION": descripcion,
        "DOCUMENTO": documento,
        "TIENDA": tienda,
        "SECCION": seccion,
        "F. REGISTRO": fecha,
        "VALOR": valor,
        "IVA": iva,
        "RET. FUENTE": ret_fuente,
        "RET. IVA": ret_iva,
        "RET. ICA": ret_ica,
        "OTROS IMP.": otros_imp,
        "VALOR PAG": valor_pag,
        "DOC.SOPORTE": doc_soporte
    }

def parse_FS(line, voucher):
    """Parsea vouchers tipo FS."""
    m = pat_documento_fs_pair.search(line)
    if not m:
        return None
    documento = f"{m.group(1)} {m.group(2)}"
    doc_start = m.start()
    descripcion = normalize_whitespace(line[len(voucher):doc_start])

    tail = line[m.end():].strip()
    mfecha = pat_fecha.search(tail)
    if not mfecha:
        return None
    fecha = mfecha.group(0)
    before_date = tail.split(fecha,1)[0].strip()

    adm_idx = re.search(r"\bADM\.", before_date, flags=re.IGNORECASE)
    tienda = before_date[adm_idx.start():].strip() if adm_idx else before_date

    nums = extract_numeric_values_after_date(tail.split(fecha,1)[1])
    while len(nums) < 8:
        nums.append("0")
    valor, iva, ret_fuente, ret_iva, ret_ica, otros_imp, valor_pag = nums[:7]
    doc_soporte = nums[7]

    return {
        "VOUCHER": voucher,
        "DESCRIPCION": descripcion,
        "DOCUMENTO": documento,
        "TIENDA": tienda,
        "SECCION": "",
        "F. REGISTRO": fecha,
        "VALOR": valor,
        "IVA": iva,
        "RET. FUENTE": ret_fuente,
        "RET. IVA": ret_iva,
        "RET. ICA": ret_ica,
        "OTROS IMP.": otros_imp,
        "VALOR PAG": valor_pag,
        "DOC.SOPORTE": doc_soporte
    }

def parse_CH(line, voucher):
    """Parsea vouchers tipo CH o registros con sección fija (RPL, DCA, etc.)."""
    mfecha = pat_fecha.search(line)
    if not mfecha:
        return None
    fecha = mfecha.group(0)
    pre_date = line[len(voucher):mfecha.start()].strip()
    adm_idx = re.search(r"\bADM\.", pre_date, flags=re.IGNORECASE)
    if adm_idx:
        descripcion = normalize_whitespace(pre_date[:adm_idx.start()])
        tienda = pre_date[adm_idx.start():].strip()
    else:
        descripcion = pre_date
        tienda = ""

    # Extraer valores numéricos
    nums = extract_numeric_values_after_date(line[mfecha.end():])
    while len(nums) < 8:
        nums.append("0")
    valor, iva, ret_fuente, ret_iva, ret_ica, otros_imp, valor_pag = nums[:7]
    doc_soporte = nums[7]

    return {
        "VOUCHER": voucher,
        "DESCRIPCION": descripcion,
        "DOCUMENTO": "",
        "TIENDA": tienda,
        "SECCION": "",
        "F. REGISTRO": fecha,
        "VALOR": valor,
        "IVA": iva,
        "RET. FUENTE": ret_fuente,
        "RET. IVA": ret_iva,
        "RET. ICA": ret_ica,
        "OTROS IMP.": otros_imp,
        "VALOR PAG": valor_pag,
        "DOC.SOPORTE": doc_soporte
    }

def parse_generic(line, voucher):
    """Intento de parseo genérico si no entra en los tipos anteriores."""
    for fn in (parse_DEC, parse_PMP, parse_FS, parse_CH):
        r = fn(line, voucher)
        if r:
            return r
    # Fallback
    mfecha = pat_fecha.search(line)
    if not mfecha:
        return None
    fecha = mfecha.group(0)
    descripcion = normalize_whitespace(line[len(voucher):mfecha.start()])
    nums = extract_numeric_values_after_date(line[mfecha.end():])
    while len(nums) < 8:
        nums.append("0")
    valor, iva, ret_fuente, ret_iva, ret_ica, otros_imp, valor_pag = nums[:7]
    doc_soporte = nums[7]
    return {
        "VOUCHER": voucher,
        "DESCRIPCION": descripcion,
        "DOCUMENTO": "",
        "TIENDA": "",
        "SECCION": "",
        "F. REGISTRO": fecha,
        "VALOR": valor,
        "IVA": iva,
        "RET. FUENTE": ret_fuente,
        "RET. IVA": ret_iva,
        "RET. ICA": ret_ica,
        "OTROS IMP.": otros_imp,
        "VALOR PAG": valor_pag,
        "DOC.SOPORTE": doc_soporte
    }

# -----------------------
# Dispatcher principal
# -----------------------
def parse_record(line: str):
    line = normalize_whitespace(line)
    m_start = re.match(rf"^{VOUCHERS}\b", line, flags=re.IGNORECASE)
    if not m_start:
        return None
    voucher = m_start.group(1).upper()

    if voucher in {"DCA", "DCF", "DND", "DAV", "DCC", "RPL"}:
        return parse_CH(line, voucher)  # sección fija
    if voucher == "DEC":
        return parse_DEC(line, voucher)
    if voucher in {"LTG", "FPM"}:
        return parse_PMP(line, voucher)
    if voucher == "FS":
        return parse_FS(line, voucher)
    if voucher == "CH":
        return parse_CH(line, voucher)

    return parse_generic(line, voucher)

# ------------------------
# Lectura y parseo PDF
# ------------------------
records = []
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        txt = page.extract_text()
        if not txt:
            continue
        lines = txt.split("\n")
        # Saltar encabezado
        for i, l in enumerate(lines):
            if l.strip().startswith("VOUCHER"):
                lines = lines[i+1:]
                break
        merged = merge_lines(lines)
        for rec_line in merged:
            parsed = parse_record(rec_line)
            if parsed:
                records.append(parsed)

# ------------------------
# Crear DataFrame
# ------------------------
cols = [
    "VOUCHER","DESCRIPCION","DOCUMENTO","TIENDA","SECCION",
    "F. REGISTRO","VALOR","IVA","RET. FUENTE","RET. IVA",
    "RET. ICA","OTROS IMP.","VALOR PAG","DOC.SOPORTE"
]
df = pd.DataFrame(records)
for c in cols:
    if c not in df.columns:
        df[c] = ""
df = df[cols]

# ------------------------
# Separar DOCUMENTO + TIENDA pegados (especial DEC)
# ------------------------
pat_merged = re.compile(r"^(\d{4}-\d{7,20})([A-ZÁÉÍÓÚÑ0-9 .-]+)$", flags=re.IGNORECASE)
for idx, row in df.iterrows():
    doc = str(row["DOCUMENTO"]).strip()
    tienda = str(row["TIENDA"]).strip()
    if not doc and tienda:
        m = pat_merged.match(tienda.replace(" ", ""))
        if m:
            df.at[idx, "DOCUMENTO"] = m.group(1)
            df.at[idx, "TIENDA"] = normalize_whitespace(m.group(2))

# ------------------------
# Extraer SECCION pegada en DESCRIPCION o TIENDA
# ------------------------
secciones_sorted = sorted(SECCIONES, key=lambda s: -len(s))

def extract_and_move_section_from_text(text: str):
    if not isinstance(text, str):
        return text, ""
    txt_low = text.lower()
    for sec in secciones_sorted:
        sec_low = sec.lower()
        idx = txt_low.rfind(sec_low)
        if idx != -1:
            seccion = text[idx:idx+len(sec)]
            new_text = re.sub(r"\s+", " ", (text[:idx] + text[idx+len(sec):]).strip())
            return new_text, seccion.upper()
    return text, ""

def fix_row_move_section(row):
    desc = str(row.get("DESCRIPCION", "")).strip()
    tienda = str(row.get("TIENDA", "")).strip()
    seccion_actual = str(row.get("SECCION", "")).strip()

    new_desc, found = extract_and_move_section_from_text(desc)
    if found:
        row["DESCRIPCION"] = new_desc
        row["SECCION"] = found
        tienda = tienda.replace(found, "").strip()
        row["TIENDA"] = re.sub(r"\s+", " ", tienda)
        return row

    new_tienda, found = extract_and_move_section_from_text(tienda)
    if found:
        row["TIENDA"] = new_tienda
        row["SECCION"] = found
        return row

    row["DESCRIPCION"] = re.sub(r"\s+", " ", desc)
    row["TIENDA"] = re.sub(r"\s+", " ", tienda)
    row["SECCION"] = seccion_actual
    return row

df = df.apply(fix_row_move_section, axis=1)

# Validar SECCION
df["SECCION"] = df["SECCION"].fillna("").str.upper().str.strip()
df.loc[~df["SECCION"].isin(SECCIONES), "SECCION"] = ""
df["TIENDA"] = df["TIENDA"].astype(str).str.strip()

# PARCHES
# Ajuste nombre de columnas:
df = df.rename(columns={
    "VALOR": "VALOR FAC.",
    "IVA": "IVA FAC."
})
# Parche para casos puntuales por no poder leer registros multi-línea
for idx, row in df.iterrows():
    # DESCRIPCION específica para RPL
    if row["VOUCHER"] == "RPL" and row["DESCRIPCION"].strip().upper() == "DESCUENTO":
        df.at[idx, "DESCRIPCION"] = "DESCUENTO COMERCIAL"

    # Ajuste de SECCION
    if row["SECCION"].strip().upper() == "DROGUE":
        df.at[idx, "SECCION"] = "DROGUER"

    # Ajustes específicos de TIENDA
    tienda_val = row["TIENDA"].strip().upper()
    if tienda_val == "PLAT - CROSS":
        df.at[idx, "TIENDA"] = "PLAT - CROSS DOCKIN"
    elif tienda_val == "PLAT - PLAT":
        df.at[idx, "TIENDA"] = "PLAT - PLAT BUCARAM"
    elif tienda_val == "PLAT - CROSSD":
        df.at[idx, "TIENDA"] = "PLAT - CROSSD AVERI"

# %%
# ------------------------
# Parche para casos puntuales por no poder leer registros multi-línea
# Mejora redacción de DESCRIPCION, SECCION y TIENDA
# ------------------------
for idx, row in df.iterrows():
    # DESCRIPCION específica para RPL
    if row["VOUCHER"] == "RPL" and row["DESCRIPCION"].strip().upper() == "DESCUENTO":
        df.at[idx, "DESCRIPCION"] = "DESCUENTO COMERCIAL"

    # Ajuste de SECCION
    if row["SECCION"].strip().upper() == "DROGUE":
        df.at[idx, "SECCION"] = "DROGUER"

    # Ajustes específicos de TIENDA
    tienda_val = row["TIENDA"].strip().upper()
    if tienda_val == "PLAT - CROSS":
        df.at[idx, "TIENDA"] = "PLAT - CROSS DOCKIN"
    elif tienda_val == "PLAT - PLAT":
        df.at[idx, "TIENDA"] = "PLAT - PLAT BUCARAM"
    elif tienda_val == "PLAT - CROSSD":
        df.at[idx, "TIENDA"] = "PLAT - CROSSD AVERI"

# %%
df.head(1000)
# Out:
#     VOUCHER          DESCRIPCION        DOCUMENTO               TIENDA  \
# 0        FS        FACTURA VENTA     VPP1 2004529  ADM. FIDELIDAD - SE
# 1        FS        FACTURA VENTA     VPP1 2004621  ADM. FIDELIDAD - SE
# 2        FS        FACTURA VENTA     VPP1 2004622  ADM. FIDELIDAD - SE
# 3        FS        FACTURA VENTA     VPP2 2021716    ADM. JUMBO - SEDE
# 4        FS        FACTURA VENTA     VPP2 2022342    ADM. JUMBO - SEDE
# 5        CH  Costo de Transferen                     ADM. JUMBO - SEDE
# 6       DEC  DTO POR ESCALA VOLU  0006-0002270331        METRO PALMIRA
# 7       DEC  DTO POR ESCALA VOLU  0006-0002270320        METRO PALMIRA
# 8       DEC  DTO POR ESCALA VOLU  0006-0002270319        METRO PALMIRA
# 9       DEC  DTO POR ESCALA VOLU  0006-0002270315        METRO PALMIRA
# 10      DEC  DTO POR ESCALA VOLU  0003-0002270336        JUMBO BULEVAR
# 11      DEC  DTO POR ESCALA VOLU  0003-0002270293        JUMBO BULEVAR
# 12      DEC  DTO POR ESCALA VOLU  0003-0002270300        JUMBO BULEVAR
# 13      DEC  DTO POR ESCALA VOLU  0003-0002270299        JUMBO BULEVAR
# 14      DEC  DTO POR ESCALA VOLU  0003-0002270298        JUMBO BULEVAR
# 15      DEC  DTO POR ESCALA VOLU  0010-0002270374           METRO BOSA
# 16      DEC  DTO POR ESCALA VOLU  0009-0002270346      JUMBO UNICENTRO
# 17      DEC  DTO POR ESCALA VOLU  0009-0002270345      JUMBO UNICENTRO
# 18      DEC  DTO POR ESCALA VOLU  0010-0002270365           METRO BOSA
# 19      DEC  DTO POR ESCALA VOLU  0010-0002270364           METRO BOSA
# 20      DEC  DTO POR ESCALA VOLU  0010-0002270360           METRO BOSA
# 21      DEC  DTO POR ESCALA VOLU  0010-0002270363           METRO BOSA
# 22      DEC  DTO POR ESCALA VOLU  0009-0002270367      JUMBO UNICENTRO
# 23      DEC  DTO POR ESCALA VOLU  0006-0002270321        METRO PALMIRA
# 24      DEC  DTO POR ESCALA VOLU  0009-0002270344      JUMBO UNICENTRO
# 25      DEC  DTO POR ESCALA VOLU  0009-0002270338      JUMBO UNICENTRO
# 26      DEC  DTO POR ESCALA VOLU  0011-0002270383          JUMBO CL 80
# 27      DEC  DTO POR ESCALA VOLU  0011-0002270425          JUMBO CL 80
# 28      DEC  DTO POR ESCALA VOLU  0013-0002270408       JUMBO VALLE DE
# 29      DEC  DTO POR ESCALA VOLU  0013-0002270438       JUMBO VALLE DE
# 30      DEC  DTO POR ESCALA VOLU  0011-0002270386          JUMBO CL 80
# 31      DEC  DTO POR ESCALA VOLU  0011-0002270387          JUMBO CL 80
# 32      DEC  DTO POR ESCALA VOLU  0011-0002270388          JUMBO CL 80
# 33      DEC  DTO POR ESCALA VOLU  0014-0002270435         JUMBO CL 170
# 34      DEC  DTO POR ESCALA VOLU  0014-0002270431         JUMBO CL 170
# 35      DEC  DTO POR ESCALA VOLU  0014-0002270437         JUMBO CL 170
# 36      DEC  DTO POR ESCALA VOLU  0014-0002270436         JUMBO CL 170
# 37      DEC  DTO POR ESCALA VOLU  0013-0002270413       JUMBO VALLE DE
# 38      DEC  DTO POR ESCALA VOLU  0013-0002270412       JUMBO VALLE DE
# 39      DEC  DTO POR ESCALA VOLU  0013-0002270414       JUMBO VALLE DE
# 40      DEC  DTO POR ESCALA VOLU  0015-0002270456       JUMBO HAYUELOS
# 41      DEC  DTO POR ESCALA VOLU  0016-0002270481     JUMBO CARRERA 30
# 42      DEC  DTO POR ESCALA VOLU  0015-0002270462       JUMBO HAYUELOS
# 43      DEC  DTO POR ESCALA VOLU  0015-0002270461       JUMBO HAYUELOS
# 44      DEC  DTO POR ESCALA VOLU  0014-0002270474         JUMBO CL 170
# 45      DEC  DTO POR ESCALA VOLU  0015-0002270463       JUMBO HAYUELOS
# 46      DEC  DTO POR ESCALA VOLU  0015-0002270498       JUMBO HAYUELOS
# 47      DEC  DTO POR ESCALA VOLU  0017-0002270523    JUMBO 20 DE JULIO
# 48      DEC  DTO POR ESCALA VOLU  0017-0002270508    JUMBO 20 DE JULIO
# 49      DEC  DTO POR ESCALA VOLU  0017-0002270510    JUMBO 20 DE JULIO
# 50      DEC  DTO POR ESCALA VOLU  0017-0002270509    JUMBO 20 DE JULIO
# 51      DEC  DTO POR ESCALA VOLU  0017-0002270504    JUMBO 20 DE JULIO
# 52      DEC  DTO POR ESCALA VOLU  0016-0002270485     JUMBO CARRERA 30
# 53      DEC  DTO POR ESCALA VOLU  0016-0002270487     JUMBO CARRERA 30
# 54      DEC  DTO POR ESCALA VOLU  0016-0002270486     JUMBO CARRERA 30
# 55      DEC  DTO POR ESCALA VOLU  0016-0002270514     JUMBO CARRERA 30
# 56      DEC  DTO POR ESCALA VOLU  0018-0002270531      JUMBO AUTOPISTA
# 57      DEC  DTO POR ESCALA VOLU  0019-0002270551      JUMBO SANTA ANA
# 58      DEC  DTO POR ESCALA VOLU  0018-0002270549      JUMBO AUTOPISTA
# 59      DEC  DTO POR ESCALA VOLU  0018-0002270533      JUMBO AUTOPISTA
# 60      DEC  DTO POR ESCALA VOLU  0018-0002270532      JUMBO AUTOPISTA
# 61      DEC  DTO POR ESCALA VOLU  0018-0002270527      JUMBO AUTOPISTA
# 62      DEC  DTO POR ESCALA VOLU  0022-0002270581      JUMBO LAS VEGAS
# 63      DEC  DTO POR ESCALA VOLU  0022-0002270580      JUMBO LAS VEGAS
# 64      DEC  DTO POR ESCALA VOLU  0022-0002270576      JUMBO LAS VEGAS
# 65      DEC  DTO POR ESCALA VOLU  0022-0002270608      JUMBO LAS VEGAS
# 66      DEC  DTO POR ESCALA VOLU  0022-0002270582      JUMBO LAS VEGAS
# 67      DEC  DTO POR ESCALA VOLU  0019-0002270559      JUMBO SANTA ANA
# 68      DEC  DTO POR ESCALA VOLU  0019-0002270557      JUMBO SANTA ANA
# 69      DEC  DTO POR ESCALA VOLU  0019-0002270602      JUMBO SANTA ANA
# 70      DEC  DTO POR ESCALA VOLU  0019-0002270558      JUMBO SANTA ANA
# 71      DEC  DTO POR ESCALA VOLU  0023-0002270601       JUMBO DE LA 65
# 72      DEC  DTO POR ESCALA VOLU  0024-0002270630        JUMBO PREMIUM
# 73      DEC  DTO POR ESCALA VOLU  0024-0002270631        JUMBO PREMIUM
# 74      DEC  DTO POR ESCALA VOLU  0024-0002270626        JUMBO PREMIUM
# 75      DEC  DTO POR ESCALA VOLU  0024-0002270655        JUMBO PREMIUM
# 76      DEC  DTO POR ESCALA VOLU  0023-0002270633       JUMBO DE LA 65
# 77      DEC  DTO POR ESCALA VOLU  0023-0002270605       JUMBO DE LA 65
# 78      DEC  DTO POR ESCALA VOLU  0023-0002270606       JUMBO DE LA 65
# 79      DEC  DTO POR ESCALA VOLU  0023-0002270607       JUMBO DE LA 65
# 80      DEC  DTO POR ESCALA VOLU  0026-0002270675       METRO BANDERAS
# 81      DEC  DTO POR ESCALA VOLU  0026-0002270674       METRO BANDERAS
# 82      DEC  DTO POR ESCALA VOLU  0026-0002270676       METRO BANDERAS
# 83      DEC  DTO POR ESCALA VOLU  0024-0002270632        JUMBO PREMIUM
# 84      DEC  DTO POR ESCALA VOLU  0025-0002270652          METRO BELLO
# 85      DEC  DTO POR ESCALA VOLU  0025-0002270654          METRO BELLO
# 86      DEC  DTO POR ESCALA VOLU  0025-0002270653          METRO BELLO
# 87      DEC  DTO POR ESCALA VOLU  0025-0002270668          METRO BELLO
# 88      DEC  DTO POR ESCALA VOLU  0025-0002270648          METRO BELLO
# 89      DEC  DTO POR ESCALA VOLU  0027-0002270699       JUMBO RIONEGRO
# 90      DEC  DTO POR ESCALA VOLU  0027-0002270698       JUMBO RIONEGRO
# 91      DEC  DTO POR ESCALA VOLU  0027-0002270700       JUMBO RIONEGRO
# 92      DEC  DTO POR ESCALA VOLU  0027-0002270725       JUMBO RIONEGRO
# 93      DEC  DTO POR ESCALA VOLU  0026-0002270671       METRO BANDERAS
# 94      DEC  DTO POR ESCALA VOLU  0026-0002270685       METRO BANDERAS
# 95      DEC  DTO POR ESCALA VOLU  0027-0002270694       JUMBO RIONEGRO
# 96      DEC  DTO POR ESCALA VOLU  0030-0002270740        JUMBO LIMONAR
# 97      DEC  DTO POR ESCALA VOLU  0030-0002270771        JUMBO LIMONAR
# 98      DEC  DTO POR ESCALA VOLU  0031-0002270767     JUMBO CHIPICHAPE
# 99      DEC  DTO POR ESCALA VOLU  0031-0002270768     JUMBO CHIPICHAPE
# 100     DEC  DTO POR ESCALA VOLU  0031-0002270795     JUMBO CHIPICHAPE
# 101     DEC  DTO POR ESCALA VOLU  0028-0002270723        METRO DUITAMA
# 102     DEC  DTO POR ESCALA VOLU  0028-0002270738        METRO DUITAMA
# 103     DEC  DTO POR ESCALA VOLU  0028-0002270722        METRO DUITAMA
# 104     DEC  DTO POR ESCALA VOLU  0028-0002270724        METRO DUITAMA
# 105     DEC  DTO POR ESCALA VOLU  0028-0002270718        METRO DUITAMA
# 106     DEC  DTO POR ESCALA VOLU  0030-0002270747        JUMBO LIMONAR
# 107     DEC  DTO POR ESCALA VOLU  0030-0002270746        JUMBO LIMONAR
# 108     DEC  DTO POR ESCALA VOLU  0030-0002270745        JUMBO LIMONAR
# 109     DEC  DTO POR ESCALA VOLU  0032-0002270788          METRO LA 70
# 110     DEC  DTO POR ESCALA VOLU  0032-0002270787          METRO LA 70
# 111     DEC  DTO POR ESCALA VOLU  0032-0002270789          METRO LA 70
# 112     DEC  DTO POR ESCALA VOLU  0033-0002270814        METRO CARTAGO
# 113     DEC  DTO POR ESCALA VOLU  0033-0002270813        METRO CARTAGO
# 114     DEC  DTO POR ESCALA VOLU  0031-0002270769     JUMBO CHIPICHAPE
# 115     DEC  DTO POR ESCALA VOLU  0032-0002270784          METRO LA 70
# 116     DEC  DTO POR ESCALA VOLU  0032-0002270800          METRO LA 70
# 117     DEC  DTO POR ESCALA VOLU  0031-0002270762     JUMBO CHIPICHAPE
# 118     DEC  DTO POR ESCALA VOLU  0034-0002270836                METRO
# 119     DEC  DTO POR ESCALA VOLU  0033-0002270807        METRO CARTAGO
# 120     DEC  DTO POR ESCALA VOLU  0034-0002270835                METRO
# 121     DEC  DTO POR ESCALA VOLU  0034-0002270834                METRO
# 122     DEC  DTO POR ESCALA VOLU  0033-0002270812        METRO CARTAGO
# 123     DEC  DTO POR ESCALA VOLU  0033-0002270827        METRO CARTAGO
# 124     DEC  DTO POR ESCALA VOLU  0034-0002270846                METRO
# 125     DEC  DTO POR ESCALA VOLU  0034-0002270830                METRO
# 126     DEC  DTO POR ESCALA VOLU  0036-0002270878        JUMBO POPAYAN
# 127     DEC  DTO POR ESCALA VOLU  0036-0002270879        JUMBO POPAYAN
# 128     DEC  DTO POR ESCALA VOLU  0036-0002270874        JUMBO POPAYAN
# 129     DEC  DTO POR ESCALA VOLU  0038-0002270905          METRO NEIVA
# 130     DEC  DTO POR ESCALA VOLU  0036-0002270880        JUMBO POPAYAN
# 131     DEC  DTO POR ESCALA VOLU  0036-0002270895        JUMBO POPAYAN
# 132     DEC  DTO POR ESCALA VOLU  0038-0002270904          METRO NEIVA
# 133     DEC  DTO POR ESCALA VOLU  0038-0002270903          METRO NEIVA
# 134     DEC  DTO POR ESCALA VOLU  0035-0002270855           METRO BUGA
# 135     DEC  DTO POR ESCALA VOLU  0035-0002270856           METRO BUGA
# 136     DEC  DTO POR ESCALA VOLU  0035-0002270871           METRO BUGA
# 137     DEC  DTO POR ESCALA VOLU  0035-0002270857           METRO BUGA
# 138     DEC  DTO POR ESCALA VOLU  0035-0002270852           METRO BUGA
# 139     DEC  DTO POR ESCALA VOLU  0039-0002270934          METRO GIRON
# 140     DEC  DTO POR ESCALA VOLU  0040-0002270949       METRO RIOHACHA
# 141     DEC  DTO POR ESCALA VOLU  0040-0002270948       METRO RIOHACHA
# 142     DEC  DTO POR ESCALA VOLU  0040-0002270950       METRO RIOHACHA
# 143     DEC  DTO POR ESCALA VOLU  0040-0002270944       METRO RIOHACHA
# 144     DEC  DTO POR ESCALA VOLU  0040-0002270959       METRO RIOHACHA
# 145     DEC  DTO POR ESCALA VOLU  0038-0002270898          METRO NEIVA
# 146     DEC  DTO POR ESCALA VOLU  0039-0002270925          METRO GIRON
# 147     DEC  DTO POR ESCALA VOLU  0039-0002270927          METRO GIRON
# 148     DEC  DTO POR ESCALA VOLU  0039-0002270926          METRO GIRON
# 149     DEC  DTO POR ESCALA VOLU  0039-0002270921          METRO GIRON
# 150     DEC  DTO POR ESCALA VOLU  0038-0002270917          METRO NEIVA
# 151     DEC  DTO POR ESCALA VOLU  0042-0002270967         METRO IBAGUE
# 152     DEC  DTO POR ESCALA VOLU  0043-0002270996          JUMBO ALTOS
# 153     DEC  DTO POR ESCALA VOLU  0042-0002270974         METRO IBAGUE
# 154     DEC  DTO POR ESCALA VOLU  0042-0002270973         METRO IBAGUE
# 155     DEC  DTO POR ESCALA VOLU  0042-0002270972         METRO IBAGUE
# 156     DEC  DTO POR ESCALA VOLU  0042-0002270986         METRO IBAGUE
# 157     DEC  DTO POR ESCALA VOLU  0044-0002271017           JUMBO CHIA
# 158     DEC  DTO POR ESCALA VOLU  0044-0002271013           JUMBO CHIA
# 159     DEC  DTO POR ESCALA VOLU  0044-0002271051           JUMBO CHIA
# 160     DEC  DTO POR ESCALA VOLU  0044-0002271019           JUMBO CHIA
# 161     DEC  DTO POR ESCALA VOLU  0044-0002271018           JUMBO CHIA
# 162     DEC  DTO POR ESCALA VOLU  0043-0002270994          JUMBO ALTOS
# 163     DEC  DTO POR ESCALA VOLU  0043-0002271021          JUMBO ALTOS
# 164     DEC  DTO POR ESCALA VOLU  0043-0002270990          JUMBO ALTOS
# 165     DEC  DTO POR ESCALA VOLU  0043-0002270995          JUMBO ALTOS
# 166     DEC  DTO POR ESCALA VOLU  0046-0002271065         METRO ITAGUI
# 167     DEC  DTO POR ESCALA VOLU  0046-0002271061         METRO ITAGUI
# 168     DEC  DTO POR ESCALA VOLU  0045-0002271043          JUMBO SANTA
# 169     DEC  DTO POR ESCALA VOLU  0045-0002271045          JUMBO SANTA
# 170     DEC  DTO POR ESCALA VOLU  0045-0002271044          JUMBO SANTA
# 171     DEC  DTO POR ESCALA VOLU  0045-0002271037          JUMBO SANTA
# 172     DEC  DTO POR ESCALA VOLU  0045-0002271065          JUMBO SANTA
# 173     DEC  DTO POR ESCALA VOLU  0048-0002271136         JUMBO SOACHA
# 174     DEC  DTO POR ESCALA VOLU  0048-0002271113         JUMBO SOACHA
# 175     DEC  DTO POR ESCALA VOLU  0048-0002271112         JUMBO SOACHA
# 176     DEC  DTO POR ESCALA VOLU  0048-0002271108         JUMBO SOACHA
# 177     DEC  DTO POR ESCALA VOLU  0046-0002271067         METRO ITAGUI
# 178     DEC  DTO POR ESCALA VOLU  0046-0002271066         METRO ITAGUI
# 179     DEC  DTO POR ESCALA VOLU  0046-0002271081         METRO ITAGUI
# 180     DEC  DTO POR ESCALA VOLU  0047-0002271084       JUMBO GIRARDOT
# 181     DEC  DTO POR ESCALA VOLU  0047-0002271107       JUMBO GIRARDOT
# 182     DEC  DTO POR ESCALA VOLU  0047-0002271089       JUMBO GIRARDOT
# 183     DEC  DTO POR ESCALA VOLU  0047-0002271088       JUMBO GIRARDOT
# 184     DEC  DTO POR ESCALA VOLU  0047-0002271090       JUMBO GIRARDOT
# 185     DEC  DTO POR ESCALA VOLU  0048-0002271114         JUMBO SOACHA
# 186     DEC  DTO POR ESCALA VOLU  0071-0002271198      METRO TINTALITO
# 187     DEC  DTO POR ESCALA VOLU  0071-0002271200      METRO TINTALITO
# 188     DEC  DTO POR ESCALA VOLU  0071-0002271199      METRO TINTALITO
# 189     DEC  DTO POR ESCALA VOLU  0071-0002271210      METRO TINTALITO
# 190     DEC  DTO POR ESCALA VOLU  0071-0002271194      METRO TINTALITO
# 191     DEC  DTO POR ESCALA VOLU  0070-0002271174           JUMBO SUBA
# 192     DEC  DTO POR ESCALA VOLU  0070-0002271203           JUMBO SUBA
# 193     DEC  DTO POR ESCALA VOLU  0070-0002271175           JUMBO SUBA
# 194     DEC  DTO POR ESCALA VOLU  0070-0002271170           JUMBO SUBA
# 195     DEC  DTO POR ESCALA VOLU  0070-0002271176           JUMBO SUBA
# 196     DEC  DTO POR ESCALA VOLU  0072-0002271223       JUMBO SANTA FE
# 197     DEC  DTO POR ESCALA VOLU  0072-0002271221       JUMBO SANTA FE
# 198     DEC  DTO POR ESCALA VOLU  0072-0002271251       JUMBO SANTA FE
# 199     DEC  DTO POR ESCALA VOLU  0072-0002271222       JUMBO SANTA FE
# 200     DEC  DTO POR ESCALA VOLU  0073-0002271241       METRO MOSQUERA
# 201     DEC  DTO POR ESCALA VOLU  0073-0002271257       METRO MOSQUERA
# 202     DEC  DTO POR ESCALA VOLU  0072-0002271217       JUMBO SANTA FE
# 203     DEC  DTO POR ESCALA VOLU  0075-0002271290          METRO SIMON
# 204     DEC  DTO POR ESCALA VOLU  0075-0002271292          METRO SIMON
# 205     DEC  DTO POR ESCALA VOLU  0075-0002271291          METRO SIMON
# 206     DEC  DTO POR ESCALA VOLU  0074-0002271269     METRO FACATATIVA
# 207     DEC  DTO POR ESCALA VOLU  0074-0002271283     METRO FACATATIVA
# 208     DEC  DTO POR ESCALA VOLU  0074-0002271271     METRO FACATATIVA
# 209     DEC  DTO POR ESCALA VOLU  0074-0002271270     METRO FACATATIVA
# 210     DEC  DTO POR ESCALA VOLU  0073-0002271245       METRO MOSQUERA
# 211     DEC  DTO POR ESCALA VOLU  0073-0002271247       METRO MOSQUERA
# 212     DEC  DTO POR ESCALA VOLU  0073-0002271246       METRO MOSQUERA
# 213     DEC  DTO POR ESCALA VOLU  0074-0002271265     METRO FACATATIVA
# 214     DEC  DTO POR ESCALA VOLU  0077-0002271335      METRO ZIPAQUIRA
# 215     DEC  DTO POR ESCALA VOLU  0077-0002271334      METRO ZIPAQUIRA
# 216     DEC  DTO POR ESCALA VOLU  0076-0002271314          JUMBO TUNJA
# 217     DEC  DTO POR ESCALA VOLU  0076-0002271313          JUMBO TUNJA
# 218     DEC  DTO POR ESCALA VOLU  0076-0002271328          JUMBO TUNJA
# 219     DEC  DTO POR ESCALA VOLU  0077-0002271336      METRO ZIPAQUIRA
# 220     DEC  DTO POR ESCALA VOLU  0075-0002271287          METRO SIMON
# 221     DEC  DTO POR ESCALA VOLU  0075-0002271303          METRO SIMON
# 222     DEC  DTO POR ESCALA VOLU  0076-0002271312          JUMBO TUNJA
# 223     DEC  DTO POR ESCALA VOLU  0076-0002271307          JUMBO TUNJA
# 224     DEC  DTO POR ESCALA VOLU  0079-0002271391            METRO SAN
# 225     DEC  DTO POR ESCALA VOLU  0079-0002271375            METRO SAN
# 226     DEC  DTO POR ESCALA VOLU  0080-0002271414                METRO
# 227     DEC  DTO POR ESCALA VOLU  0079-0002271378            METRO SAN
# 228     DEC  DTO POR ESCALA VOLU  0079-0002271380            METRO SAN
# 229     DEC  DTO POR ESCALA VOLU  0079-0002271379            METRO SAN
# 230     DEC  DTO POR ESCALA VOLU  0078-0002271352       METRO FONTIBON
# 231     DEC  DTO POR ESCALA VOLU  0078-0002271356       METRO FONTIBON
# 232     DEC  DTO POR ESCALA VOLU  0078-0002271371       METRO FONTIBON
# 233     DEC  DTO POR ESCALA VOLU  0077-0002271329      METRO ZIPAQUIRA
# 234     DEC  DTO POR ESCALA VOLU  0077-0002271347      METRO ZIPAQUIRA
# 235     DEC  DTO POR ESCALA VOLU  0078-0002271358       METRO FONTIBON
# 236     DEC  DTO POR ESCALA VOLU  0078-0002271357       METRO FONTIBON
# 237     DEC  DTO POR ESCALA VOLU  0081-0002271420        METRO VENTURA
# 238     DEC  DTO POR ESCALA VOLU  0081-0002271427        METRO VENTURA
# 239     DEC  DTO POR ESCALA VOLU  0081-0002271425        METRO VENTURA
# 240     DEC  DTO POR ESCALA VOLU  0081-0002271439        METRO VENTURA
# 241     DEC  DTO POR ESCALA VOLU  0081-0002271426        METRO VENTURA
# 242     DEC  DTO POR ESCALA VOLU  0080-0002271404                METRO
# 243     DEC  DTO POR ESCALA VOLU  0080-0002271403                METRO
# 244     DEC  DTO POR ESCALA VOLU  0080-0002271402                METRO
# 245     DEC  DTO POR ESCALA VOLU  0080-0002271397                METRO
# 246     DEC  DTO POR ESCALA VOLU  0083-0002271462         JUMBO CARIBE
# 247     DEC  DTO POR ESCALA VOLU  0083-0002271492         JUMBO CARIBE
# 248     DEC  DTO POR ESCALA VOLU  0083-0002271468         JUMBO CARIBE
# 249     DEC  DTO POR ESCALA VOLU  0083-0002271467         JUMBO CARIBE
# 250     DEC  DTO POR ESCALA VOLU  0082-0002271442       METRO ATALAYAS
# 251     DEC  DTO POR ESCALA VOLU  0082-0002271446       METRO ATALAYAS
# 252     DEC  DTO POR ESCALA VOLU  0082-0002271447       METRO ATALAYAS
# 253     DEC  DTO POR ESCALA VOLU  0082-0002271445       METRO ATALAYAS
# 254     DEC  DTO POR ESCALA VOLU  0082-0002271450       METRO ATALAYAS
# 255     DEC  DTO POR ESCALA VOLU  0083-0002271469         JUMBO CARIBE
# 256     DEC  DTO POR ESCALA VOLU  0085-0002271527       METRO MONTERIA
# 257     DEC  DTO POR ESCALA VOLU  0085-0002271514       METRO MONTERIA
# 258     DEC  DTO POR ESCALA VOLU  0085-0002271509       METRO MONTERIA
# 259     DEC  DTO POR ESCALA VOLU  0084-0002271510      JUMBO MEGA MALL
# 260     DEC  DTO POR ESCALA VOLU  0084-0002271491      JUMBO MEGA MALL
# 261     DEC  DTO POR ESCALA VOLU  0084-0002271490      JUMBO MEGA MALL
# 262     DEC  DTO POR ESCALA VOLU  0084-0002271492      JUMBO MEGA MALL
# 263     DEC  DTO POR ESCALA VOLU  0084-0002271486      JUMBO MEGA MALL
# 264     DEC  DTO POR ESCALA VOLU  0087-0002271563      JUMBO GUATAPURI
# 265     DEC  DTO POR ESCALA VOLU  0087-0002271565      JUMBO GUATAPURI
# 266     DEC  DTO POR ESCALA VOLU  0087-0002271564      JUMBO GUATAPURI
# 267     DEC  DTO POR ESCALA VOLU  0087-0002271579      JUMBO GUATAPURI
# 268     DEC  DTO POR ESCALA VOLU  0087-0002271557      JUMBO GUATAPURI
# 269     DEC  DTO POR ESCALA VOLU  0086-0002271533      JUMBO AMERICANO
# 270     DEC  DTO POR ESCALA VOLU  0085-0002271516       METRO MONTERIA
# 271     DEC  DTO POR ESCALA VOLU  0085-0002271515       METRO MONTERIA
# 272     DEC  DTO POR ESCALA VOLU  0086-0002271561      JUMBO AMERICANO
# 273     DEC  DTO POR ESCALA VOLU  0086-0002271540      JUMBO AMERICANO
# 274     DEC  DTO POR ESCALA VOLU  0086-0002271539      JUMBO AMERICANO
# 275     DEC  DTO POR ESCALA VOLU  0086-0002271538      JUMBO AMERICANO
# 276     DEC  DTO POR ESCALA VOLU  0088-0002271586     JUMBO BUENAVISTA
# 277     DEC  DTO POR ESCALA VOLU  0088-0002271612     JUMBO BUENAVISTA
# 278     DEC  DTO POR ESCALA VOLU  0088-0002271585     JUMBO BUENAVISTA
# 279     DEC  DTO POR ESCALA VOLU  0088-0002271584     JUMBO BUENAVISTA
# 280     DEC  DTO POR ESCALA VOLU  0088-0002271580     JUMBO BUENAVISTA
# 281     DEC  DTO POR ESCALA VOLU  0097-0002271631       METRO SOGAMOSO
# 282     DEC  DTO POR ESCALA VOLU  0097-0002271630       METRO SOGAMOSO
# 283     DEC  DTO POR ESCALA VOLU  0097-0002271632       METRO SOGAMOSO
# 284     DEC  DTO POR ESCALA VOLU  0097-0002271626       METRO SOGAMOSO
# 285     DEC  DTO POR ESCALA VOLU  0097-0002271644       METRO SOGAMOSO
# 286     DEC  DTO POR ESCALA VOLU  0103-0002271649       JUMBO CABECERA
# 287     DEC  DTO POR ESCALA VOLU  0108-0002271678      JUMBO CANAVERAL
# 288     DEC  DTO POR ESCALA VOLU  0108-0002271677      JUMBO CANAVERAL
# 289     DEC  DTO POR ESCALA VOLU  0108-0002271673      JUMBO CANAVERAL
# 290     DEC  DTO POR ESCALA VOLU  0108-0002271703      JUMBO CANAVERAL
# 291     DEC  DTO POR ESCALA VOLU  0103-0002271655       JUMBO CABECERA
# 292     DEC  DTO POR ESCALA VOLU  0103-0002271656       JUMBO CABECERA
# 293     DEC  DTO POR ESCALA VOLU  0103-0002271654       JUMBO CABECERA
# 294     DEC  DTO POR ESCALA VOLU  0103-0002271674       JUMBO CABECERA
# 295     DEC  DTO POR ESCALA VOLU  0124-0002271713       METRO ALQUERIA
# 296     DEC  DTO POR ESCALA VOLU  0124-0002271712       METRO ALQUERIA
# 297     DEC  DTO POR ESCALA VOLU  0124-0002271714       METRO ALQUERIA
# 298     DEC  DTO POR ESCALA VOLU  0108-0002271679      JUMBO CANAVERAL
# 299     DEC  DTO POR ESCALA VOLU  0126-0002271734            JUMBO SAN
# 300     DEC  DTO POR ESCALA VOLU  0126-0002271730            JUMBO SAN
# 301     DEC  DTO POR ESCALA VOLU  0126-0002271746            JUMBO SAN
# 302     DEC  DTO POR ESCALA VOLU  0124-0002271726       METRO ALQUERIA
# 303     DEC  DTO POR ESCALA VOLU  0126-0002271736            JUMBO SAN
# 304     DEC  DTO POR ESCALA VOLU  0126-0002271735            JUMBO SAN
# 305     DEC  DTO POR ESCALA VOLU  0124-0002271708       METRO ALQUERIA
# 306     DEC  DTO POR ESCALA VOLU  0128-0002271766          JUMBO PASTO
# 307     DEC  DTO POR ESCALA VOLU  0148-0002271817        JUMBO SANTAFE
# 308     DEC  DTO POR ESCALA VOLU  0128-0002271778          JUMBO PASTO
# 309     DEC  DTO POR ESCALA VOLU  0148-0002271793        JUMBO SANTAFE
# 310     DEC  DTO POR ESCALA VOLU  0148-0002271789        JUMBO SANTAFE
# 311     DEC  DTO POR ESCALA VOLU  0128-0002271768          JUMBO PASTO
# 312     DEC  DTO POR ESCALA VOLU  0128-0002271767          JUMBO PASTO
# 313     DEC  DTO POR ESCALA VOLU  0128-0002271761          JUMBO PASTO
# 314     DEC  DTO POR ESCALA VOLU  0166-0002271831                METRO
# 315     DEC  DTO POR ESCALA VOLU  0166-0002271830                METRO
# 316     DEC  DTO POR ESCALA VOLU  0166-0002271832                METRO
# 317     DEC  DTO POR ESCALA VOLU  0166-0002271844                METRO
# 318     DEC  DTO POR ESCALA VOLU  0167-0002271853          JUMBO TITAN
# 319     DEC  DTO POR ESCALA VOLU  0148-0002271794        JUMBO SANTAFE
# 320     DEC  DTO POR ESCALA VOLU  0148-0002271795        JUMBO SANTAFE
# 321     DEC  DTO POR ESCALA VOLU  0166-0002271826                METRO
# 322     DEC  DTO POR ESCALA VOLU  0171-0002271877          METRO PASTO
# 323     DEC  DTO POR ESCALA VOLU  0171-0002271876          METRO PASTO
# 324     DEC  DTO POR ESCALA VOLU  0171-0002271875          METRO PASTO
# 325     DEC  DTO POR ESCALA VOLU  0174-0002271902    JUMBO EL CASTILLO
# 326     DEC  DTO POR ESCALA VOLU  0174-0002271903    JUMBO EL CASTILLO
# 327     DEC  DTO POR ESCALA VOLU  0174-0002271901    JUMBO EL CASTILLO
# 328     DEC  DTO POR ESCALA VOLU  0167-0002271876          JUMBO TITAN
# 329     DEC  DTO POR ESCALA VOLU  0167-0002271848          JUMBO TITAN
# 330     DEC  DTO POR ESCALA VOLU  0171-0002271870          METRO PASTO
# 331     DEC  DTO POR ESCALA VOLU  0171-0002271884          METRO PASTO
# 332     DEC  DTO POR ESCALA VOLU  0167-0002271851          JUMBO TITAN
# 333     DEC  DTO POR ESCALA VOLU  0167-0002271852          JUMBO TITAN
# 334     DEC  DTO POR ESCALA VOLU  0179-0002271933       METRO PITALITO
# 335     DEC  DTO POR ESCALA VOLU  0179-0002271926       METRO PITALITO
# 336     DEC  DTO POR ESCALA VOLU  0179-0002271928       METRO PITALITO
# 337     DEC  DTO POR ESCALA VOLU  0179-0002271927       METRO PITALITO
# 338     DEC  DTO POR ESCALA VOLU  0183-0002271945        METRO SAN GIL
# 339     DEC  DTO POR ESCALA VOLU  0183-0002271954        METRO SAN GIL
# 340     DEC  DTO POR ESCALA VOLU  0174-0002271923    JUMBO EL CASTILLO
# 341     DEC  DTO POR ESCALA VOLU  0174-0002271896    JUMBO EL CASTILLO
# 342     DEC  DTO POR ESCALA VOLU  0179-0002271920       METRO PITALITO
# 343     DEC  DTO POR ESCALA VOLU  0184-0002271976        METRO MAYALES
# 344     DEC  DTO POR ESCALA VOLU  0184-0002271975        METRO MAYALES
# 345     DEC  DTO POR ESCALA VOLU  0184-0002271974        METRO MAYALES
# 346     DEC  DTO POR ESCALA VOLU  0185-0002272011          JUMBO YOPAL
# 347     DEC  DTO POR ESCALA VOLU  0185-0002272000          JUMBO YOPAL
# 348     DEC  DTO POR ESCALA VOLU  0185-0002271993          JUMBO YOPAL
# 349     DEC  DTO POR ESCALA VOLU  0183-0002271950        METRO SAN GIL
# 350     DEC  DTO POR ESCALA VOLU  0183-0002271951        METRO SAN GIL
# 351     DEC  DTO POR ESCALA VOLU  0183-0002271949        METRO SAN GIL
# 352     DEC  DTO POR ESCALA VOLU  0184-0002271969        METRO MAYALES
# 353     DEC  DTO POR ESCALA VOLU  0184-0002271984        METRO MAYALES
# 354     DEC  DTO POR ESCALA VOLU  0193-0002272045          JUMBO PLAZA
# 355     DEC  DTO POR ESCALA VOLU  0193-0002272049          JUMBO PLAZA
# 356     DEC  DTO POR ESCALA VOLU  0191-0002272028     JUMBO BAZAR CHIA
# 357     DEC  DTO POR ESCALA VOLU  0191-0002272027     JUMBO BAZAR CHIA
# 358     DEC  DTO POR ESCALA VOLU  0191-0002272057     JUMBO BAZAR CHIA
# 359     DEC  DTO POR ESCALA VOLU  0193-0002272051          JUMBO PLAZA
# 360     DEC  DTO POR ESCALA VOLU  0193-0002272050          JUMBO PLAZA
# 361     DEC  DTO POR ESCALA VOLU  0193-0002272065          JUMBO PLAZA
# 362     DEC  DTO POR ESCALA VOLU  0185-0002272002          JUMBO YOPAL
# 363     DEC  DTO POR ESCALA VOLU  0185-0002272001          JUMBO YOPAL
# 364     DEC  DTO POR ESCALA VOLU  0191-0002272026     JUMBO BAZAR CHIA
# 365     DEC  DTO POR ESCALA VOLU  0191-0002272023     JUMBO BAZAR CHIA
# 366     DEC  DTO POR ESCALA VOLU  0195-0002272097          METRO SANTA
# 367     DEC  DTO POR ESCALA VOLU  0195-0002272096          METRO SANTA
# 368     DEC  DTO POR ESCALA VOLU  0195-0002272095          METRO SANTA
# 369     DEC  DTO POR ESCALA VOLU  0194-0002272075       JUMBO ATLANTIS
# 370     DEC  DTO POR ESCALA VOLU  0194-0002272077       JUMBO ATLANTIS
# 371     DEC  DTO POR ESCALA VOLU  0194-0002272076       JUMBO ATLANTIS
# 372     DEC  DTO POR ESCALA VOLU  0194-0002272068       JUMBO ATLANTIS
# 373     DEC  DTO POR ESCALA VOLU  0195-0002272090          METRO SANTA
# 374     DEC  DTO POR ESCALA VOLU  0195-0002272105          METRO SANTA
# 375     DEC  DTO POR ESCALA VOLU  0253-0002272158            JBO ATRIO
# 376     DEC  DTO POR ESCALA VOLU  0253-0002272163            JBO ATRIO
# 377     DEC  DTO POR ESCALA VOLU  0253-0002272162            JBO ATRIO
# 378     DEC  DTO POR ESCALA VOLU  0255-0002272178                 J255
# 379     DEC  DTO POR ESCALA VOLU  0253-0002272161            JBO ATRIO
# 380     DEC  DTO POR ESCALA VOLU  0249-0002272143          JBO ALTOS D
# 381     DEC  DTO POR ESCALA VOLU  0249-0002272173          JBO ALTOS D
# 382     DEC  DTO POR ESCALA VOLU  0249-0002272141          JBO ALTOS D
# 383     DEC  DTO POR ESCALA VOLU  0249-0002272142          JBO ALTOS D
# 384     DEC  DTO POR ESCALA VOLU  0249-0002272137          JBO ALTOS D
# 385     DEC  DTO POR ESCALA VOLU  0806-0002272241          METRO PRADO
# 386     DEC  DTO POR ESCALA VOLU  0806-0002272243          METRO PRADO
# 387     DEC  DTO POR ESCALA VOLU  0806-0002272242          METRO PRADO
# 388     DEC  DTO POR ESCALA VOLU  0806-0002272253          METRO PRADO
# 389     DEC  DTO POR ESCALA VOLU  0806-0002272237          METRO PRADO
# 390     DEC  DTO POR ESCALA VOLU  0255-0002272182                 J255
# 391     DEC  DTO POR ESCALA VOLU  0255-0002272181                 J255
# 392     DEC  DTO POR ESCALA VOLU  0255-0002272183                 J255
# 393     LTG  DIF. COSTO/CANTIDAD       PMP1283012       PLAT - ELECTRO
# 394     LTG  DIF. COSTO/CANTIDAD       PMP1284119    PLAT - PLAT CROSS
# 395     LTG  DIF. COSTO/CANTIDAD       PMP1284462  PLAT - CROSSD AVERI
# 396     LTG  DIF. COSTO/CANTIDAD       PMP1284117    PLAT - PLAT CROSS
# 397     LTG  DIF. COSTO/CANTIDAD       PMP1282099               PLAT -
# 398     LTG  DIF. COSTO/CANTIDAD       PMP1282964  PLAT - CROSS DOCKIN
# 399     LTG  DIF. COSTO/CANTIDAD       PMP1284460    PLAT - PLATAFORMA
# 400     LTG  DIF. COSTO/CANTIDAD       PMP1284114    PLAT - PLAT CROSS
# 401     LTG  DIF. COSTO/CANTIDAD       PMP1284200  PLAT - CROSSD AVERI
# 402     LTG  DIF. COSTO/CANTIDAD       PMP1283784    PLAT - PLAT CROSS
# 403     LTG  DIF. COSTO/CANTIDAD       PMP1283785    PLAT - PLAT CROSS
# 404     LTG  DIF. COSTO/CANTIDAD       PMP1283476  PLAT - PLAT BUCARAM
# 405     LTG  DIF. COSTO/CANTIDAD       PMP1283500  PLAT - CROSS DOCKIN
# 406     LTG  DIF. COSTO/CANTIDAD       PMP1284878  PLAT - CROSSD AVERI
# 407     LTG  DIF. COSTO/CANTIDAD       PMP1284876  PLAT - CROSSD AVERI
# 408     LTG  DIF. COSTO/CANTIDAD       PMP1284879  PLAT - CROSSD AVERI
# 409     LTG  DIF. COSTO/CANTIDAD       PMP1284543  PLAT - CROSS DOCKIN
# 410     LTG  DIF. COSTO/CANTIDAD       PMP1284546  PLAT - CROSS DOCKIN
# 411     LTG  DIF. COSTO/CANTIDAD       PMP1284750    PLAT - PLAT CROSS
# 412     LTG  DIF. COSTO/CANTIDAD       PMP1284529  PLAT - CROSS DOCKIN
# 413     LTG  DIF. COSTO/CANTIDAD       PMP1282353      PLAT - ALMAGRAN
# 414     LTG  DIF. COSTO/CANTIDAD       PMP1284948  PLAT - CROSS DOCKIN
# 415     LTG  DIF. COSTO/CANTIDAD       PMP1284949  PLAT - CROSS DOCKIN
# 416     LTG  DIF. COSTO/CANTIDAD       PMP1284951  PLAT - CROSS DOCKIN
# 417     LTG  DIF. COSTO/CANTIDAD       PMP1284602  PLAT - PLAT BUCARAM
# 418     LTG  DIF. COSTO/CANTIDAD       PMP1285908  PLAT - CROSSD AVERI
# 419     LTG  DIF. COSTO/CANTIDAD       PMP1285903  PLAT - CROSSD AVERI
# 420     LTG  DIF. COSTO/CANTIDAD       PMP1285071  PLAT - CROSS DOCKIN
# 421     LTG  DIF. COSTO/CANTIDAD       PMP1285067  PLAT - CROSS DOCKIN
# 422     LTG  DIF. COSTO/CANTIDAD       PMP1285059  PLAT - CROSS DOCKIN
# 423     LTG  DIF. COSTO/CANTIDAD       PMP1285065  PLAT - CROSS DOCKIN
# 424     LTG  DIF. COSTO/CANTIDAD       PMP1285048  PLAT - PLAT BUCARAM
# 425     LTG  DIF. COSTO/CANTIDAD       PMP1285898  PLAT - CROSSD AVERI
# 426     LTG  DIF. COSTO/CANTIDAD       PMP1284800  PLAT - CROSS DOCKIN
# 427     LTG  DIF. COSTO/CANTIDAD       PMP1286710  PLAT - CROSS DOCKIN
# 428     LTG  DIF. COSTO/CANTIDAD       PMP1286716  PLAT - CROSS DOCKIN
# 429     LTG  DIF. COSTO/CANTIDAD       PMP1286208  PLAT - CROSS DOCKIN
# 430     LTG  DIF. COSTO/CANTIDAD       PMP1286712  PLAT - CROSS DOCKIN
# 431     LTG  DIF. COSTO/CANTIDAD       PMP1286709  PLAT - CROSS DOCKIN
# 432     LTG  DIF. COSTO/CANTIDAD       PMP1286711  PLAT - CROSS DOCKIN
# 433     LTG  DIF. COSTO/CANTIDAD       PMP1286715  PLAT - CROSS DOCKIN
# 434     LTG  DIF. COSTO/CANTIDAD       PMP1285725  PLAT - PLAT BUCARAM
# 435     LTG  DIF. COSTO/CANTIDAD       PMP1284950  PLAT - CROSS DOCKIN
# 436     LTG  DIF. COSTO/CANTIDAD       PMP1285659  PLAT - CROSS DOCKIN
# 437     LTG  DIF. COSTO/CANTIDAD       PMP1283008  PLAT - PLAT BUCARAM
# 438     LTG  DIF. COSTO/CANTIDAD       PMP1285653  PLAT - CROSS DOCKIN
# 439     LTG  DIF. COSTO/CANTIDAD       PMP1286554    PLAT - PLAT CROSS
# 440     LTG  DIF. COSTO/CANTIDAD       PMP1287321  PLAT - PLAT BUCARAM
# 441     LTG  DIF. COSTO/CANTIDAD       PMP1286056  PLAT - PLAT BUCARAM
# 442     LTG  DIF. COSTO/CANTIDAD       PMP1287335  PLAT - PLAT BUCARAM
# 443     LTG  DIF. COSTO/CANTIDAD       PMP1287951  PLAT - CROSS DOCKIN
# 444     LTG  DIF. COSTO/CANTIDAD       PMP1287957  PLAT - CROSS DOCKIN
# 445     LTG  DIF. COSTO/CANTIDAD       PMP1287948  PLAT - CROSS DOCKIN
# 446     LTG  DIF. COSTO/CANTIDAD       PMP1286556    PLAT - PLAT CROSS
# 447     LTG  DIF. COSTO/CANTIDAD       PMP1288418  PLAT - CROSS DOCKIN
# 448     LTG  DIF. COSTO/CANTIDAD       PMP1287325  PLAT - PLAT BUCARAM
# 449     LTG  DIF. COSTO/CANTIDAD       PMP1287736    PLAT - PLAT CROSS
# 450     LTG  DIF. COSTO/CANTIDAD       PMP1287829    PLAT - PLAT CROSS
# 451     LTG  DIF. COSTO/CANTIDAD       PMP1288731  PLAT - CROSSD AVERI
# 452     LTG  DIF. COSTO/CANTIDAD       PMP1287930  PLAT - PLAT BUCARAM
# 453     LTG  DIF. COSTO/CANTIDAD       PMP1287931  PLAT - PLAT BUCARAM
# 454     LTG  DIF. COSTO/CANTIDAD       PMP1287928  PLAT - PLAT BUCARAM
# 455     LTG  DIF. COSTO/CANTIDAD       PMP1287257  PLAT - PLAT BUCARAM
# 456     LTG  DIF. COSTO/CANTIDAD       PMP1287574  PLAT - CROSS DOCKIN
# 457     LTG  DIF. COSTO/CANTIDAD       PMP1287949  PLAT - CROSS DOCKIN
# 458     LTG  DIF. COSTO/CANTIDAD     PMP128777746    PLAT - PLAT CROSS
# 459     LTG  DIF. COSTO/CANTIDAD       PMP1287386  PLAT - CROSSD AVERI
# 460     LTG  DIF. COSTO/CANTIDAD       PMP1287385  PLAT - CROSSD AVERI
# 461     LTG  DIF. COSTO/CANTIDAD       PMP1287379  PLAT - CROSSD AVERI
# 462     LTG  DIF. COSTO/CANTIDAD       PMP1288989  PLAT - CROSS DOCKIN
# 463     LTG  DIF. COSTO/CANTIDAD       PMP1288988  PLAT - CROSS DOCKIN
# 464     LTG  DIF. COSTO/CANTIDAD       PMP1289253  PLAT - CROSS DOCKIN
# 465     LTG  DIF. COSTO/CANTIDAD       PMP1288987  PLAT - CROSS DOCKIN
# 466     LTG  DIF. COSTO/CANTIDAD       PMP1289251  PLAT - CROSS DOCKIN
# 467     LTG  DIF. COSTO/CANTIDAD       PMP1289507  PLAT - CROSSD AVERI
# 468     LTG  DIF. COSTO/CANTIDAD       PMP1287921  PLAT - CROSS DOCKIN
# 469     LTG  DIF. COSTO/CANTIDAD       PMP1288919  PLAT - PLAT BUCARAM
# 470     LTG  DIF. COSTO/CANTIDAD       PMP1288926  PLAT - PLAT BUCARAM
# 471     LTG  DIF. COSTO/CANTIDAD       PMP1289328  PLAT - PLAT BUCARAM
# 472     LTG  DIF. COSTO/CANTIDAD       PMP1287903  PLAT - CROSS DOCKIN
# 473     LTG  DIF. COSTO/CANTIDAD       PMP1289326  PLAT - PLAT BUCARAM
# 474     LTG  DIF. COSTO/CANTIDAD       PMP1287920  PLAT - CROSS DOCKIN
# 475     LTG  DIF. COSTO/CANTIDAD       PMP1287904  PLAT - CROSS DOCKIN
# 476     LTG  DIF. COSTO/CANTIDAD       PMP1289324  PLAT - PLAT BUCARAM
# 477     FPM    FACTURA PROVEEDOR       PMP1284464  PLAT - CROSSD AVERI
# 478     FPM    FACTURA PROVEEDOR       PMP1284463  PLAT - CROSSD AVERI
# 479     FPM    FACTURA PROVEEDOR       PMP1284461  PLAT - CROSSD AVERI
# 480     FPM    FACTURA PROVEEDOR       PMP1282399  PLAT - CROSS DOCKIN
# 481     FPM    FACTURA PROVEEDOR       PMP1282298  PLAT - CROSS DOCKIN
# 482     FPM    FACTURA PROVEEDOR       PMP1282303  PLAT - CROSS DOCKIN
# 483     FPM    FACTURA PROVEEDOR       PMP1284465  PLAT - CROSSD AVERI
# 484     FPM    FACTURA PROVEEDOR       PMP1284466  PLAT - CROSSD AVERI
# 485     FPM    FACTURA PROVEEDOR       PMP1284206  PLAT - CROSSD AVERI
# 486     FPM    FACTURA PROVEEDOR       PMP1284462  PLAT - CROSSD AVERI
# 487     FPM    FACTURA PROVEEDOR       PMP1283012       PLAT - ELECTRO
# 488     FPM    FACTURA PROVEEDOR       PMP1284111    PLAT - PLAT CROSS
# 489     FPM    FACTURA PROVEEDOR       PMP1284113    PLAT - PLAT CROSS
# 490     FPM    FACTURA PROVEEDOR       PMP1284110    PLAT - PLAT CROSS
# 491     FPM    FACTURA PROVEEDOR       PMP1284117    PLAT - PLAT CROSS
# 492     FPM    FACTURA PROVEEDOR       PMP1283567    PLAT - PLAT CROSS
# 493     FPM    FACTURA PROVEEDOR       PMP1284119    PLAT - PLAT CROSS
# 494     FPM    FACTURA PROVEEDOR       PMP1283578    PLAT - PLAT CROSS
# 495     FPM    FACTURA PROVEEDOR       PMP1284112    PLAT - PLAT CROSS
# 496     FPM    FACTURA PROVEEDOR       PMP1283576    PLAT - PLAT CROSS
# 497     FPM    FACTURA PROVEEDOR       PMP1283788    PLAT - PLAT CROSS
# 498     FPM    FACTURA PROVEEDOR       PMP1283787    PLAT - PLAT CROSS
# 499     FPM    FACTURA PROVEEDOR       PMP1283786    PLAT - PLAT CROSS
# 500     FPM    FACTURA PROVEEDOR       PMP1282964  PLAT - CROSS DOCKIN
# 501     FPM    FACTURA PROVEEDOR       PMP1282962  PLAT - CROSS DOCKIN
# 502     FPM    FACTURA PROVEEDOR       PMP1282099               PLAT -
# 503     FPM    FACTURA PROVEEDOR       PMP1283674  PLAT - PLAT BUCARAM
# 504     FPM    FACTURA PROVEEDOR       PMP1283673  PLAT - PLAT BUCARAM
# 505     FPM    FACTURA PROVEEDOR       PMP1283672  PLAT - PLAT BUCARAM
# 506     FPM    FACTURA PROVEEDOR       PMP1284460    PLAT - PLATAFORMA
# 507     FPM    FACTURA PROVEEDOR       PMP1282291   PLAT - PLT ANCHETA
# 508     FPM    FACTURA PROVEEDOR       PMP1284548  PLAT - CROSS DOCKIN
# 509     FPM    FACTURA PROVEEDOR       PMP1284544  PLAT - CROSS DOCKIN
# 510     FPM    FACTURA PROVEEDOR       PMP1284549  PLAT - CROSS DOCKIN
# 511     FPM    FACTURA PROVEEDOR       PMP1283513  PLAT - CROSS DOCKIN
# 512     FPM    FACTURA PROVEEDOR       PMP1284528  PLAT - CROSS DOCKIN
# 513     FPM    FACTURA PROVEEDOR       PMP1284530  PLAT - CROSS DOCKIN
# 514     FPM    FACTURA PROVEEDOR       PMP1283501  PLAT - CROSS DOCKIN
# 515     FPM    FACTURA PROVEEDOR       PMP1283518  PLAT - CROSS DOCKIN
# 516     FPM    FACTURA PROVEEDOR       PMP1284547  PLAT - CROSS DOCKIN
# 517     FPM    FACTURA PROVEEDOR       PMP1283503  PLAT - CROSS DOCKIN
# 518     FPM    FACTURA PROVEEDOR       PMP1284545  PLAT - CROSS DOCKIN
# 519     FPM    FACTURA PROVEEDOR       PMP1283500  PLAT - CROSS DOCKIN
# 520     FPM    FACTURA PROVEEDOR       PMP1284617  PLAT - PLAT BUCARAM
# 521     FPM    FACTURA PROVEEDOR       PMP1284618  PLAT - PLAT BUCARAM
# 522     FPM    FACTURA PROVEEDOR       PMP1284619  PLAT - PLAT BUCARAM
# 523     FPM    FACTURA PROVEEDOR       PMP1283667  PLAT - PLAT BUCARAM
# 524     FPM    FACTURA PROVEEDOR       PMP1283668  PLAT - PLAT BUCARAM
# 525     FPM    FACTURA PROVEEDOR       PMP1283670  PLAT - PLAT BUCARAM
# 526     FPM    FACTURA PROVEEDOR       PMP1283669  PLAT - PLAT BUCARAM
# 527     FPM    FACTURA PROVEEDOR       PMP1283671  PLAT - PLAT BUCARAM
# 528     FPM    FACTURA PROVEEDOR       PMP1283476  PLAT - PLAT BUCARAM
# 529     FPM    FACTURA PROVEEDOR       PMP1284116    PLAT - PLAT CROSS
# 530     FPM    FACTURA PROVEEDOR       PMP1284115    PLAT - PLAT CROSS
# 531     FPM    FACTURA PROVEEDOR       PMP1284114    PLAT - PLAT CROSS
# 532     FPM    FACTURA PROVEEDOR       PMP1283785    PLAT - PLAT CROSS
# 533     FPM    FACTURA PROVEEDOR       PMP1283569    PLAT - PLAT CROSS
# 534     FPM    FACTURA PROVEEDOR       PMP1284118    PLAT - PLAT CROSS
# 535     FPM    FACTURA PROVEEDOR       PMP1283784    PLAT - PLAT CROSS
# 536     FPM    FACTURA PROVEEDOR       PMP1284880  PLAT - CROSSD AVERI
# 537     FPM    FACTURA PROVEEDOR       PMP1284204  PLAT - CROSSD AVERI
# 538     FPM    FACTURA PROVEEDOR       PMP1284205  PLAT - CROSSD AVERI
# 539     FPM    FACTURA PROVEEDOR       PMP1284202  PLAT - CROSSD AVERI
# 540     FPM    FACTURA PROVEEDOR       PMP1284203  PLAT - CROSSD AVERI
# 541     FPM    FACTURA PROVEEDOR       PMP1284200  PLAT - CROSSD AVERI
# 542     FPM    FACTURA PROVEEDOR       PMP1284201  PLAT - CROSSD AVERI
# 543     FPM    FACTURA PROVEEDOR       PMP1284750    PLAT - PLAT CROSS
# 544     FPM    FACTURA PROVEEDOR       PMP1284529  PLAT - CROSS DOCKIN
# 545     FPM    FACTURA PROVEEDOR       PMP1284947  PLAT - CROSS DOCKIN
# 546     FPM    FACTURA PROVEEDOR       PMP1284546  PLAT - CROSS DOCKIN
# 547     FPM    FACTURA PROVEEDOR       PMP1282353      PLAT - ALMAGRAN
# 548     FPM    FACTURA PROVEEDOR       PMP1284367  PLAT - CROSS DOCKIN
# 549     FPM    FACTURA PROVEEDOR       PMP1284543  PLAT - CROSS DOCKIN
# 550     FPM    FACTURA PROVEEDOR       PMP1284371  PLAT - CROSS DOCKIN
# 551     FPM    FACTURA PROVEEDOR       PMP1284878  PLAT - CROSSD AVERI
# 552     FPM    FACTURA PROVEEDOR       PMP1284879  PLAT - CROSSD AVERI
# 553     FPM    FACTURA PROVEEDOR       PMP1284876  PLAT - CROSSD AVERI
# 554     FPM    FACTURA PROVEEDOR       PMP1285566  PLAT - CROSSD AVERI
# 555     FPM    FACTURA PROVEEDOR       PMP1285910  PLAT - CROSSD AVERI
# 556     FPM    FACTURA PROVEEDOR       PMP1285565  PLAT - CROSSD AVERI
# 557     FPM    FACTURA PROVEEDOR       PMP1284369  PLAT - CROSS DOCKIN
# 558     FPM    FACTURA PROVEEDOR       PMP1284368  PLAT - CROSS DOCKIN
# 559     FPM    FACTURA PROVEEDOR       PMP1284951  PLAT - CROSS DOCKIN
# 560     FPM    FACTURA PROVEEDOR       PMP1284948  PLAT - CROSS DOCKIN
# 561     FPM    FACTURA PROVEEDOR       PMP1284949  PLAT - CROSS DOCKIN
# 562     FPM    FACTURA PROVEEDOR       PMP1285904  PLAT - CROSSD AVERI
# 563     FPM    FACTURA PROVEEDOR       PMP1285897  PLAT - CROSSD AVERI
# 564     FPM    FACTURA PROVEEDOR       PMP1285909  PLAT - CROSSD AVERI
# 565     FPM    FACTURA PROVEEDOR       PMP1285564  PLAT - CROSSD AVERI
# 566     FPM    FACTURA PROVEEDOR       PMP1285907  PLAT - CROSSD AVERI
# 567     FPM    FACTURA PROVEEDOR       PMP1285906  PLAT - CROSSD AVERI
# 568     FPM    FACTURA PROVEEDOR       PMP1285905  PLAT - CROSSD AVERI
# 569     FPM    FACTURA PROVEEDOR       PMP1285569  PLAT - CROSSD AVERI
# 570     FPM    FACTURA PROVEEDOR       PMP1285567  PLAT - CROSSD AVERI
# 571     FPM    FACTURA PROVEEDOR       PMP1283382  PLAT - CROSS DOCKIN
# 572     FPM    FACTURA PROVEEDOR       PMP1285070  PLAT - CROSS DOCKIN
# 573     FPM    FACTURA PROVEEDOR       PMP1285058  PLAT - CROSS DOCKIN
# 574     FPM    FACTURA PROVEEDOR       PMP1285057  PLAT - CROSS DOCKIN
# 575     FPM    FACTURA PROVEEDOR       PMP1285066  PLAT - CROSS DOCKIN
# 576     FPM    FACTURA PROVEEDOR       PMP1285068  PLAT - CROSS DOCKIN
# 577     FPM    FACTURA PROVEEDOR       PMP1285062  PLAT - CROSS DOCKIN
# 578     FPM    FACTURA PROVEEDOR       PMP1285061  PLAT - CROSS DOCKIN
# 579     FPM    FACTURA PROVEEDOR       PMP1283381  PLAT - CROSS DOCKIN
# 580     FPM    FACTURA PROVEEDOR       PMP1285044  PLAT - PLAT BUCARAM
# 581     FPM    FACTURA PROVEEDOR       PMP1285046  PLAT - PLAT BUCARAM
# 582     FPM    FACTURA PROVEEDOR       PMP1284601  PLAT - PLAT BUCARAM
# 583     FPM    FACTURA PROVEEDOR       PMP1284602  PLAT - PLAT BUCARAM
# 584     FPM    FACTURA PROVEEDOR       PMP1285568  PLAT - CROSSD AVERI
# 585     FPM    FACTURA PROVEEDOR       PMP1284877  PLAT - CROSSD AVERI
# 586     FPM    FACTURA PROVEEDOR       PMP1285908  PLAT - CROSSD AVERI
# 587     FPM    FACTURA PROVEEDOR       PMP1285903  PLAT - CROSSD AVERI
# 588     FPM    FACTURA PROVEEDOR       PMP1284541  PLAT - CROSS DOCKIN
# 589     FPM    FACTURA PROVEEDOR       PMP1284542  PLAT - CROSS DOCKIN
# 590     FPM    FACTURA PROVEEDOR       PMP1285896  PLAT - CROSSD AVERI
# 591     FPM    FACTURA PROVEEDOR       PMP1285894  PLAT - CROSSD AVERI
# 592     FPM    FACTURA PROVEEDOR       PMP1285901  PLAT - CROSSD AVERI
# 593     FPM    FACTURA PROVEEDOR       PMP1285900  PLAT - CROSSD AVERI
# 594     FPM    FACTURA PROVEEDOR       PMP1285902  PLAT - CROSSD AVERI
# 595     FPM    FACTURA PROVEEDOR       PMP1285898  PLAT - CROSSD AVERI
# 596     FPM    FACTURA PROVEEDOR       PMP1285899  PLAT - CROSSD AVERI
# 597     FPM    FACTURA PROVEEDOR       PMP1285895  PLAT - CROSSD AVERI
# 598     FPM    FACTURA PROVEEDOR       PMP1284799  PLAT - CROSS DOCKIN
# 599     FPM    FACTURA PROVEEDOR       PMP1286201  PLAT - CROSS DOCKIN
# 600     FPM    FACTURA PROVEEDOR       PMP1286206  PLAT - CROSS DOCKIN
# 601     FPM    FACTURA PROVEEDOR       PMP1286267  PLAT - CROSS DOCKIN
# 602     FPM    FACTURA PROVEEDOR       PMP1284798  PLAT - CROSS DOCKIN
# 603     FPM    FACTURA PROVEEDOR       PMP1284801  PLAT - CROSS DOCKIN
# 604     FPM    FACTURA PROVEEDOR       PMP1285660  PLAT - CROSS DOCKIN
# 605     FPM    FACTURA PROVEEDOR       PMP1285649  PLAT - CROSS DOCKIN
# 606     FPM    FACTURA PROVEEDOR       PMP1285624  PLAT - CROSS DOCKIN
# 607     FPM    FACTURA PROVEEDOR       PMP1285064  PLAT - CROSS DOCKIN
# 608     FPM    FACTURA PROVEEDOR       PMP1285626  PLAT - CROSS DOCKIN
# 609     FPM    FACTURA PROVEEDOR       PMP1285069  PLAT - CROSS DOCKIN
# 610     FPM    FACTURA PROVEEDOR       PMP1285059  PLAT - CROSS DOCKIN
# 611     FPM    FACTURA PROVEEDOR       PMP1285056  PLAT - CROSS DOCKIN
# 612     FPM    FACTURA PROVEEDOR       PMP1285072  PLAT - CROSS DOCKIN
# 613     FPM    FACTURA PROVEEDOR       PMP1285650  PLAT - CROSS DOCKIN
# 614     FPM    FACTURA PROVEEDOR       PMP1285071  PLAT - CROSS DOCKIN
# 615     FPM    FACTURA PROVEEDOR       PMP1285067  PLAT - CROSS DOCKIN
# 616     FPM    FACTURA PROVEEDOR       PMP1285060  PLAT - CROSS DOCKIN
# 617     FPM    FACTURA PROVEEDOR       PMP1285063  PLAT - CROSS DOCKIN
# 618     FPM    FACTURA PROVEEDOR       PMP1285065  PLAT - CROSS DOCKIN
# 619     FPM    FACTURA PROVEEDOR       PMP1283010  PLAT - PLAT BUCARAM
# 620     FPM    FACTURA PROVEEDOR       PMP1283009  PLAT - PLAT BUCARAM
# 621     FPM    FACTURA PROVEEDOR       PMP1283007  PLAT - PLAT BUCARAM
# 622     FPM    FACTURA PROVEEDOR       PMP1285727  PLAT - PLAT BUCARAM
# 623     FPM    FACTURA PROVEEDOR       PMP1285045  PLAT - PLAT BUCARAM
# 624     FPM    FACTURA PROVEEDOR       PMP1285726  PLAT - PLAT BUCARAM
# 625     FPM    FACTURA PROVEEDOR       PMP1285047  PLAT - PLAT BUCARAM
# 626     FPM    FACTURA PROVEEDOR       PMP1285048  PLAT - PLAT BUCARAM
# 627     FPM    FACTURA PROVEEDOR       PMP1286309    PLAT - PLAT CROSS
# 628     FPM    FACTURA PROVEEDOR       PMP1286551    PLAT - PLAT CROSS
# 629     FPM    FACTURA PROVEEDOR       PMP1286312    PLAT - PLAT CROSS
# 630     FPM    FACTURA PROVEEDOR       PMP1286315    PLAT - PLAT CROSS
# 631     FPM    FACTURA PROVEEDOR       PMP1286314    PLAT - PLAT CROSS
# 632     FPM    FACTURA PROVEEDOR       PMP1286308    PLAT - PLAT CROSS
# 633     FPM    FACTURA PROVEEDOR       PMP1286561    PLAT - PLAT CROSS
# 634     FPM    FACTURA PROVEEDOR       PMP1286557    PLAT - PLAT CROSS
# 635     FPM    FACTURA PROVEEDOR       PMP1284800  PLAT - CROSS DOCKIN
# 636     FPM    FACTURA PROVEEDOR       PMP1286208  PLAT - CROSS DOCKIN
# 637     FPM    FACTURA PROVEEDOR       PMP1286207  PLAT - CROSS DOCKIN
# 638     FPM    FACTURA PROVEEDOR       PMP1286713  PLAT - CROSS DOCKIN
# 639     FPM    FACTURA PROVEEDOR       PMP1284946  PLAT - CROSS DOCKIN
# 640     FPM    FACTURA PROVEEDOR       PMP1286712  PLAT - CROSS DOCKIN
# 641     FPM    FACTURA PROVEEDOR       PMP1284950  PLAT - CROSS DOCKIN
# 642     FPM    FACTURA PROVEEDOR       PMP1286233  PLAT - CROSS DOCKIN
# 643     FPM    FACTURA PROVEEDOR       PMP1286714  PLAT - CROSS DOCKIN
# 644     FPM    FACTURA PROVEEDOR       PMP1286234  PLAT - CROSS DOCKIN
# 645     FPM    FACTURA PROVEEDOR       PMP1286711  PLAT - CROSS DOCKIN
# 646     FPM    FACTURA PROVEEDOR       PMP1284802  PLAT - CROSS DOCKIN
# ...
# 616        0           0     -3.274.224                   0
# 617        0           0     -3.645.876                   0
# 618        0           0     -5.917.494                   0
# 619        0           0    -16.254.460                   0
# 620        0           0     -1.370.292                   0
# 621        0           0     -2.477.647                   0
# 622        0           0    -10.407.494                   0
# 623        0           0    -98.026.994                   0
# 624        0           0    -25.229.551                   0
# 625        0           0    -23.302.839                   0
# 626        0           0   -145.248.957                   0
# 627        0           0       -556.095                   0
# 628        0           0    -21.001.683                   0
# 629        0           0       -967.156                   0
# 630        0           0     -4.055.023                   0
# 631        0           0     -4.232.133                   0
# 632        0           0    -12.932.898                   0
# 633        0           0     -2.431.522                   0
# 634        0           0    -11.342.074                   0
# 635        0           0     -6.176.671                   0
# 636        0           0     -5.681.834                   0
# 637        0           0     -1.216.003                   0
# 638        0           0     -4.029.601                   0
# 639        0           0    -36.319.313                   0
# 640        0           0   -220.423.969                   0
# 641        0           0    -62.862.488                   0
# 642        0           0    -22.494.170                   0
# 643        0           0    -40.294.707                   0
# 644        0           0     -1.752.000                   0
# 645        0           0    -53.872.282                   0
# 646        0           0     -1.678.749                   0
# 647        0           0   -156.110.758                   0
# 648        0           0    -53.421.092                   0
# 649        0           0    -87.745.055                   0
# 650        0           0   -105.120.352                   0
# 651        0           0     -1.697.734                   0
# 652        0           0    -18.374.573                   0
# 653        0           0       -436.315                   0
# 654        0           0    -56.694.028                   0
# 655        0           0     -4.422.869                   0
# 656        0           0     -1.746.130                   0
# 657        0           0   -199.872.244                   0
# 658        0           0    -55.214.529                   0
# 659        0           0     -9.590.545                   0
# 660        0           0    -48.682.179                   0
# 661        0           0    -56.119.506                   0
# 662        0           0       -279.123                   0
# 663        0           0     -2.823.842                   0
# 664        0           0     -2.289.761                   0
# 665        0           0    -56.609.882                   0
# 666        0           0     -1.265.638                   0
# 667        0           0     -9.646.811                   0
# 668        0           0     -1.922.034                   0
# 669        0           0    -10.095.284                   0
# 670        0           0     -1.828.028                   0
# 671        0           0     -9.623.338                   0
# 672        0           0     -2.546.997                   0
# 673        0           0    -15.469.605                   0
# 674        0           0     -8.639.877                   0
# 675        0           0    -20.225.654                   0
# 676        0           0    -15.631.310                   0
# 677        0           0     -1.320.846                   0
# 678        0           0    -12.881.478                   0
# 679        0           0    -38.720.670                   0
# 680        0           0     -1.787.500                   0
# 681        0           0     -3.061.105                   0
# 682        0           0    -52.874.675                   0
# 683        0           0    -74.107.638                   0
# 684        0           0     -3.227.009                   0
# 685        0           0     -7.544.702                   0
# 686        0           0    -21.499.283                   0
# 687        0           0     -8.014.466                   0
# 688        0           0   -146.399.056                   0
# 689        0           0     -1.262.543                   0
# 690        0           0     -8.815.143                   0
# 691        0           0   -122.718.449                   0
# 692        0           0    -42.615.075                   0
# 693        0           0       -538.999                   0
# 694        0           0     -1.980.697                   0
# 695        0           0     -3.452.490                   0
# 696        0           0     -5.720.068                   0
# 697        0           0       -249.830                   0
# 698        0           0       -909.443                   0
# 699        0           0     -3.196.855                   0
# 700        0           0     -4.352.626                   0
# 701        0           0    -83.249.216                   0
# 702        0           0       -801.457                   0
# 703        0           0     -5.725.836                   0
# 704        0           0    -12.084.983                   0
# 705        0           0     -5.353.502                   0
# 706        0           0    -26.720.654                   0
# 707        0           0     -3.699.117                   0
# 708        0           0     -7.705.372                   0
# 709        0           0     -3.643.403                   0
# 710        0           0     -1.954.995                   0
# 711        0           0    -63.136.754                   0
# 712        0           0    -17.601.501                   0
# 713        0           0    -23.124.866                   0
# 714        0           0    -10.071.048                   0
# 715        0           0     -3.290.589                   0
# 716        0           0     -1.221.963                   0
# 717        0           0     -1.022.145                   0
# 718        0           0     -3.439.995                   0
# 719        0           0    -62.112.585                   0
# 720        0           0     -4.782.526                   0
# 721        0           0     -2.768.065                   0
# 722        0           0    -30.363.095                   0
# 723        0           0     -4.612.359                   0
# 724        0           0       -850.612                   0
# 725        0           0     -1.803.701                   0
# 726        0           0     -3.264.983                   0
# 727        0           0    -14.160.003                   0
# 728        0           0    -75.058.845                   0
# 729        0           0    -11.120.304                   0
# 730        0           0   -327.458.353                   0
# 731        0           0     -5.664.992                   0
# 732        0           0     -3.745.478                   0
# 733        0           0    -16.061.611                   0
# 734        0           0   -327.689.420                   0
# 735        0           0    -12.296.761                   0
# 736        0           0    -43.074.216                   0
# 737        0           0       -193.915                   0
# 738        0           0     -6.386.715                   0
# 739        0           0    -56.301.204                   0
# 740        0           0       -350.399                   0
# 741        0           0    -10.362.080                   0
# 742        0           0    -54.806.957                   0
# 743        0           0     -7.940.200                   0
# 744        0           0     -1.400.983                   0
# 745        0           0    -18.776.713                   0
# 746        0           0     -3.515.192                   0
# 747        0           0    -29.688.104                   0
# 748        0           0    -15.749.411                   0
# 749        0           0    -28.101.906                   0
# 750        0           0     -6.385.711                   0
# 751        0           0     -1.102.527                   0
# 752        0           0    -28.010.959                   0
# 753        0           0     -1.555.512                   0
# 754        0           0     -9.733.344                   0
# 755        0           0    -91.532.951                   0
# 756        0           0     -2.260.319                   0
# 757        0           0   -129.467.595                   0
# 758        0           0    -14.831.505                   0
# 759        0           0     -6.591.930                   0
# 760        0           0    -47.391.727                   0
# 761        0           0     -2.516.997                   0
# 762        0           0     -3.185.627                   0
# 763        0           0     -1.656.422                   0
# 764        0           0     -9.840.656                   0
# 765        0           0     -2.630.889                   0
# 766        0           0     -7.245.458                   0
# 767        0           0     -1.699.030                   0
# 768        0           0    -18.830.858                   0
# 769        0           0     -1.121.345                   0
# 770        0           0       -482.499                   0
# 771        0           0    -22.208.695                   0
# 772        0           0    -30.134.724                   0
# 773        0           0     -2.011.591                   0
# 774        0           0       -805.242                   0
# 775        0           0    -47.830.822                   0
# 776        0           0     -9.254.987                   0
# 777        0           0    -10.155.440                   0
# 778        0           0     -8.419.653                   0
# 779        0           0     -1.652.220                   0
# 780        0           0     -7.890.271                   0
# 781        0           0     -1.247.668                   0
# 782        0           0     -1.219.496                   0
# 783        0           0     -1.734.426                   0
# 784        0           0     -8.630.706                   0
# 785        0           0     -4.303.354                   0
# 786        0           0     -7.403.798                   0
# 787        0           0    -26.370.430                   0
# 788        0           0     -2.934.219                   0
# 789        0           0    -29.388.684                   0
# 790        0           0       -594.995                   0
# 791        0           0    -56.858.695                   0
# 792        0           0    -66.857.794                   0
# 793        0           0    -18.417.965                   0
# 794        0           0     -1.460.219                   0
# 795        0           0   -161.169.209                   0
# 796        0           0     -2.337.305                   0
# 797        0           0    -79.485.216                   0
# 798        0           0     -3.942.916                   0
# 799        0           0     -2.939.473                   0
# 800        0           0    -68.222.226                   0
# 801        0           0     -8.744.135                   0
# 802        0           0     -2.849.443                   0
# 803        0           0    -35.508.391                   0
# 804        0           0     -1.037.493                   0
# 805        0           0    -25.978.998                   0
# 806        0           0     -8.224.476                   0
# 807        0           0   -157.321.871                   0
# 808        0           0     -8.971.591                   0
# 809        0           0     -3.796.938                   0
# 810        0           0    -14.222.974                   0
# 811        0           0     -1.790.000                   0
# 812        0           0     -9.163.312                   0
# 813        0           0     -3.356.756                   0
# 814        0           0     -8.525.728                   0
# 815        0           0    -74.511.554                   0
# 816        0           0    -15.015.559                   0
# 817        0           0     -6.399.365                   0
# 818        0           0    -45.864.792                   0
# 819        0           0       -350.399                   0
# 820        0           0    -68.234.332                   0
# 821        0           0    -95.451.966                   0
# 822        0           0    -43.111.608                   0
# 823        0           0    -10.771.989                   0
# 824        0           0     -8.823.196                   0
# 825        0           0     -8.299.879                   0
# 826        0           0     -8.523.031                   0
# 827        0           0      1.323.072  20.251.200.199.280
# 828        0           0      6.568.413  20.181.200.033.536
# 829        0           0        130.450  20.181.100.045.651
# 830        0           0      1.777.292  20.171.100.014.225
# 831        0           0        458.230  20.222.600.126.372
# 832        0           0        942.527  20.171.100.014.225
# 833        0           0      2.606.536  20.181.100.032.054
# 834        0           0     26.364.028  20.171.100.014.225
# 835        0           0    254.331.040  20.251.200.200.036
# 836        0           0    343.622.707  20.251.100.199.918
# 837        0           0        305.488  20.222.600.126.372
# 838        0           0     61.299.192                   0
# 839        0           0      2.259.774  20.171.100.014.225
# 840        0           0    117.913.970  20.251.100.199.887
# 841        0           0        834.061  20.171.200.014.220
# 842        0           0     63.971.913  20.251.100.200.097
# 843        0           0      2.391.586  20.181.100.045.651
# 844        0           0    542.708.897  20.251.200.199.221
# 845        0           0      1.616.229  20.222.600.126.372
# 846        0           0      2.366.167  20.171.200.014.220
# 847        0           0        176.902  20.222.600.126.372
# 848        0           0      1.077.485  20.222.600.126.372
# 849        0           0      4.582.316  20.222.600.126.372
# 850        0           0         85.220  20.181.100.032.054
# 851        0           0     10.996.154  20.171.100.014.225
# 852        0           0        101.407  20.171.200.014.220
# 853        0           0     14.651.655  20.181.200.033.536
# 854        0           0      3.562.638  20.181.100.032.054
# 855        0           0     20.000.000  20.251.100.200.166
# 856        0           0        152.340  20.171.100.014.225
# 857        0           0     11.353.075  20.252.600.198.821
# 858        0           0     10.216.531                   0
# 859        0           0    532.175.699  20.251.200.199.219
# 860        0           0    408.729.662  20.251.200.199.218
# 861        0           0      8.594.192  20.251.100.200.165
# 862        0           0      1.139.265  20.171.200.014.220
# 863        0           0        499.754  20.181.100.045.651
# 864        0           0     19.461.398  20.171.200.014.220
# 865        0           0    272.000.000  20.251.100.199.957
# 866        0           0     29.638.456  20.251.400.199.149
# 867        0           0         27.260  20.181.100.045.651
# 868        0           0     19.632.788  20.251.200.200.064
# 869        0           0         11.794  20.222.600.126.372
# 870        0           0     14.258.141  20.251.200.200.056
# 871        0           0      7.026.140  20.181.200.033.536
# 872        0           0     16.162.285  20.222.600.126.372
# 873        0           0     26.582.858  20.171.200.014.220
